# %% [markdown]
# # RO47019: Intelligent Control Systems Practical Assignment
# * Period: 2025-2026, Q3
# * Course homepage: https://brightspace.tudelft.nl/d2l/home/775422
# * Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)
# * Teaching assistant: Mukil Saravanan (m.saravanan-1@student.tudelft.nl)
# * (c) TU Delft, 2026
#
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE` and remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please **do not** delete it, instead run that cell as you would run all other cells. Finally, please **do not** add any extra cells to this notebook or change the existing cells unless you are explicitly asked to do so.
#
# Please fill in your name(s) and other required details below:

# %%
# Please fill in your names, student numbers, netID, and emails below.
STUDENT_1_NAME = "Andrei Simionescu"
STUDENT_1_STUDENT_NUMBER = "5459559"
STUDENT_1_NETID = "asimionescu"
STUDENT_1_EMAIL = "asimionescu@tudelft.nl"

# %%
# Note: this block is a check that you have filled in the above information.
# It will throw an AssertionError until all fields are filled
assert STUDENT_1_NAME != ""
assert STUDENT_1_STUDENT_NUMBER != ""
assert STUDENT_1_NETID != ""
assert STUDENT_1_EMAIL != ""

# %% [markdown]
# ### General announcements
#
# * Do *not* share your solutions (also after the course is finished), and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.
#
# * Please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. Please note that it is **not** allowed to post any code relating to solution attempts. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA or if not possible otherwise, send an email to the instructor or TA.
#
# * This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for you that you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.
#
# * This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook "uneditable" or "unremovable" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment.
#
# * Please note that the above mentioned _read-only_ protection only works in Jupyter Notebook, and it does not work if you open this notebook in another editor (e.g., VSCode, PyCharm, etc.). Therefore, we recommend that you only use Jupyter Notebook for this course. If you use any other editor, you may accidentally delete cells, modify the tests, etc., which would cause you to lose points.
#
# * If you edit a function that is imported in another notebook, you need to **restart the kernel** of the notebook where you are using the function. Otherwise, the changes will not be effective.
#
# * **IMPORTANT**: Please make sure that your code executes without any errors before submitting the notebook. An easy way to ensure this is to use the validation script as described in the README.

# %% [markdown]
# # Task 1b - Vision-based angle prediction (20 points)
#
# **Authors:** Chuhan Zhang (C.Zhang-8@tudelft.nl), Tomás Coleman, Maximilian Stölzle
#
# **Warning** To help you, we have marked parts of the code where we want you to contribute. These parts are often marked with a start comment, `Task 1b.i.j: ...` and a closing comment, `Task 1b.i.j: END`. You are free to add code outside of the designated areas. However, we cannot guarantee that this won't affect the intended behavior of the code.
#
# In this file, we will implement two Convolutional Neural Network (CNN) models to predict the position of the single pendulum based on input image data. Each CNN model will try a separate way to predict angles: direct or indirect. Direct prediction means that the network outputs a prediction of the link angle $\hat \theta$, and then updates the network parameters by comparing the loss between the predicted $\hat \theta$ and the label $\theta$. However, indirect prediction means that the dataset has changed. Label is no longer a single angle, but an array containing the $\sin \theta$ value and $\cos \theta$ value of the angle. The output of the network is no longer a single $\hat \theta$, but the predicted $[\hat {\sin \theta}, \hat {\cos \theta}]$. The network updates parameters by comparing the loss between $[\sin \theta, \cos \theta]$ and $[\hat {\sin \theta}, \hat {\cos \theta}]$.
#
# The following cells import all the necessary packages and external functions to run the code properly. First, we want to check whether the images are generated properly and create the directory for output plots and models. Different dataset classes are also created from the information gathered in notebook 1a. Finally, different Pytorch data loaders will be created for each network architecture.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from os import PathLike
from pathlib import Path
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import random_split
from tqdm.notebook import tqdm  # progress bar
from typing import List, Tuple
from distutils.util import strtobool

# define boolean to check if the notebook is run for the purposes of autograding
AUTOGRADING = strtobool(os.environ.get("AUTOGRADING", "false"))


# seed the random number generators
# https://pytorch.org/docs/stable/notes/randomness.html
def manual_seed(seed: int):
    """
    Set manual seeds

    Args:
        seed: Random seed to sett.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)


class DirectoryNotFoundException(Exception):
    """
    Exception raised when a specified directory is not found.

    This exception is used to signal that an operation which expects
    a certain directory to exist has failed because the directory
    was not found in the expected location. It extends the standard
    Exception class and can be used to provide more specific error
    handling that is distinct from general exceptions.

    Attributes:
        None - Inherits all attributes and methods from the base Exception class.

    Methods:
        None - Inherits all methods from the base Exception class and does not
        define any additional behavior.
    """

    pass


class ModelTypeNotFoundException(Exception):
    """
    Exception raised when a specified model type is not found.

    This exception is used in contexts where a specific type of
    model is expected to be present or accessible, but it cannot
    be located or identified. The exception is particularly useful
    in scenarios involving machine learning or data processing
    pipelines where the absence of a required model type can lead
    to failure of the process.

    Attributes:
        None - Inherits all attributes and methods from the base Exception class.

    Methods:
        None - Inherits all methods from the base Exception class and does not
        define any additional behavior.
    """

    pass


# check the directory for datasets
DATASET_DIR = Path("datasets") / "pendulum_dataset"
if not DATASET_DIR.exists():
    raise DirectoryNotFoundException(
        f"The pendulum dataset doesn't exist yet. Please run all cells in the `task_1a_extract_dataset` notebook."
    )

# create the directory for well-trained neural network models
STATEDICTS_DIR = Path("statedicts")
STATEDICTS_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Then, we would like to prepare the training and test sets for the CNNs. In this assignment, we use two ways to predict the state: direct and indirect. Therefore, we prepare the datasets with two formats of labels, called $theta$ and $trig$ respectively.

# %%
class CNNDataset(Dataset):
    """
    A PyTorch dataset class for a CNN, designed to load images and corresponding labels.

    This class extends the PyTorch Dataset class, making it suitable for use with
    PyTorch data loaders and other utilities. It is designed to load image data
    and their associated labels from a specified directory, performing optional
    transformations on the images.
    """

    def __init__(self, dataset_path: PathLike, transform=None):
        """
        Initializes the dataset object with the data path, optional transform, and dataset length.

        Args:
            dataset_path: Path to the directory where image and label files are stored.
            transform: A function/transform that takes in an image and returns a transformed version.
        """

        self.dataset_path = Path(dataset_path)
        self.transform = transform

        # determine the total dataset length
        i = 0
        while (self.dataset_path / f"image{i}.npz").exists():
            i += 1
        self.len = i

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """
        Retrieves an image and its corresponding label at the given index `idx`. The image is
        loaded from a .npz file, optionally transformed, and then returned along with its label
        (both in position form and as sine and cosine components).

        Args:
            idx: The index of the image and label to be loaded.
        Returns:
            x: The image as a torch.Tensor, possibly transformed.
            label_theta: The position label as a torch.FloatTensor
            label_trig: A torch.FloatTensor with two elements, representing the sine and cosine
               components of the label.
        """
        x = np.array(np.load(self.dataset_path / f"image{idx}.npz")["arr_0"])
        if self.transform:
            x = self.transform(x)
        theta = np.load(self.dataset_path / f"label{idx}.npz")["arr_0"]
        sin = np.sin(theta)
        cos = np.cos(theta)

        theta = torch.tensor(np.array(theta)).type(torch.FloatTensor)
        trig = torch.tensor(np.array([sin, cos])).type(torch.FloatTensor)
        return x, theta, trig

    def __len__(self) -> int:
        """
        Returns the total number of samples available in the dataset.

        Returns:
            self.len: The total number of images (or samples) in the dataset.
        """
        return self.len

# %% [markdown]
# The size of the original image data is `500x500x3`, and we want to compress it into a smaller size to save the computation time. Therefore, we add _transforms_ for preprocessing data when building our `Dataset` object. We first use the `ToTensor()` method in PyTorch to convert pixel data distributed between `[0, 255]` into floating point tensor data distributed between `[0, 1]`. Then, we use `Grayscale()` to convert the RGB images into grayscale images. _**Optional question**: Why can we convert the input color image into a grayscale image in this task? Can this be done for all tasks?_ Then we use `CenterCrop()` to extract the center `240x240`px area of the original image, and use `Resize()` to downsample the image to `24x24`px. With this preprocessing pipeline, we obtained training data with each input sample being a tensor of dimension `24x24x1`.

# %%
IMAGE_TRANSFORM = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Grayscale(),
        transforms.CenterCrop(240),
        transforms.Resize((24, 24)),
    ]
)

# %% [markdown]
# It is worth noting that, this `DataLoader` returns three variables: the image $x$, the corresponding label $\theta$, and $[\sin \theta, \cos \theta]$ data. The `DataLoader` is consistent for direct and indirect prediction tasks. You must be careful about using underscores in your code to ignore unnecessary return values for the task.
#
# In this task, we divide the entire data set into three parts: training set, validation set, and test set. The split ratio between training, validation, and testing is 50%, 20%, and 30%. By calling the `load_dataloaders` method, the data loaders for training, validation, and testing are provided.

# %%
def load_dataloaders(
    dataset_path: PathLike,
    val_ratio: float = 0.2,
    test_ratio: float = 0.3,
    batch_size: int = 32,
) -> Tuple[DataLoader, DataLoader, DataLoader]:
    """
    Loads and returns data loaders for training, validation, and testing datasets.

    Args:
        dataset_path: Path to the directory where the dataset is stored.
        val_ratio: The ratio of the dataset to be used for validation.
                    It must be between 0 and 1. Defaults to 0.2.
        test_ratio: The ratio of the dataset to be used for testing.
                    It must be between 0 and 1. Defaults to 0.3.
        batch_size: The number of samples per batch to load. Defaults to 32.

    Returns:
        train_dataloader: The DataLoader instances for the training.
        val_dataloader: The DataLoader instances for the validation.
        test_dataloader: The DataLoader instances for the testing.

    Raises:
        AssertionError: If the sum of val_ratio and test_ratio is larger than 1.0
    """
    assert (
        0.0 <= val_ratio <= 1.0
    ), "Validation ratio needs to be in the interval [0, 1]."
    assert 0.0 <= test_ratio <= 1.0, "Test ratio needs to be in the interval [0, 1]."
    assert (
        val_ratio + test_ratio
    ) <= 1.0, "The sum of val and test ratio needs to be in the interval [0, 1]."

    dataset = CNNDataset(dataset_path, transform=IMAGE_TRANSFORM)
    print(f"The dataset contains {len(dataset)} samples")

    train_size = int(len(dataset) * (1.0 - val_ratio - test_ratio))
    val_size = int(len(dataset) * val_ratio)
    test_size = int(len(dataset) * test_ratio)

    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size]
    )

    train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size, shuffle=False)
    test_dataloader = DataLoader(test_dataset, batch_size, shuffle=False)

    return train_dataloader, val_dataloader, test_dataloader


train_loader, val_loader, test_loader = load_dataloaders(DATASET_DIR)
# Out:
# The dataset contains 3600 samples

# %% [markdown]
# We show the data after preprocessing as below. Do you still remember the colorful, high-resolution dataset samples in task 1a? Now, they have become a low-resolution grayscale image. Please feel free to visualize multiple samples by changing the respective `sample_idx` variable.

# %%
def visualize_dataset_sample(dataset_path: str, sample_idx: int = 1200) -> None:
    """
    Displays a visual representation of an example image from the dataset.

    Args:
        dataset_path: Path to the directory where the dataset is stored.
        sample_idx: The index of the sample to be visualized. Defaults to 1200.

    Returns:
        None: This function only displays an image and does not return any value.
    """
    dataset = CNNDataset(dataset_path, transform=IMAGE_TRANSFORM)
    img_example, _, _ = dataset[sample_idx]
    img_example = img_example.permute(1, 2, 0)
    plt.imshow(img_example, cmap="gray")
    plt.show()


visualize_dataset_sample(DATASET_DIR)

# %% [markdown]
# We already have the function to build training, validation, and testing dataloaders. We will package the evaluation function in the following code block.
#
# Here, during the process of training, we adopt Mean Square Error (MSE) as the loss by invoking `nn.MSELoss()` from PyTorch. During the evalutation process (also in `evaluate_model` method), we adopt Mean Absolute Error (MAE) as the error by invoking `nn.L1Loss()`. _**Optional question:** why do we use MSE in the training process instead of MAE?_

# %%
loss_fn = nn.MSELoss(reduction="mean")
error_fn = nn.L1Loss(reduction="mean")


def evaluate_model(
    model: nn.Module, eval_loader: DataLoader, model_type: str = "theta"
) -> Tuple[float, float]:
    """
    Evaluates the performance of a theta model on a test dataset.

    Args:
        model: The neural network model to be evaluated.
        eval_loader: The DataLoader for the evaluation dataset.
        model_type: The type of model to be evaluated ('theta' or 'trig').
                                    Defaults to 'theta'.

    Returns:
        loss: The mean loss of the model on the valuation dataset.
        error: The mean error of the model on the evaluation dataset.

    Raises:
        ModelTypeNotFoundException: If the provided model_type is neither 'theta' nor 'trig'.

    """
    running_loss = 0.0
    running_error = 0.0
    count = 0.0
    with torch.no_grad():
        for i, (x, theta, trig) in enumerate(eval_loader):
            if model_type == "theta":
                theta_hat = model(x).squeeze(1)

                batch_loss = loss_fn(theta, theta_hat)
                batch_error = error_fn(theta, theta_hat)
            elif model_type == "trig":
                trig_hat = model(x)
                sin_hat = trig_hat[:, 0]
                cos_hat = trig_hat[:, 1]
                sin = trig[:, 0]
                cos = trig[:, 1]
                angle_hat = torch.atan2(sin_hat, cos_hat)
                angle = torch.atan2(sin, cos)

                batch_loss = loss_fn(trig, trig_hat)
                batch_error = error_fn(angle, angle_hat)
            else:
                raise ModelTypeNotFoundException(
                    f"The model type should be either theta or trig."
                )

            running_loss += batch_loss.item()
            running_error += batch_error.item()
            count += 1

    loss = running_loss / count
    error = running_error / count

    return loss, error

# %% [markdown]
# ## Task 1b.1 - Learn to predict angles directly (9.5 points)
# We are going to create models that try to predict the link angles $\hat{\theta}$ given an image of the robot, so $\theta \approx \hat{\theta} =M(x)$.

# %% [markdown]
# ### Tasb 1b.1.1 - Create the CNN model (3.5 points)
# It's time to create a CNN model. Here, create a PyTorch model class called `CNNTheta()`.
# * Start with a convolutional layer `torch.nn.Conv2d(...)` with 32 as the output channel number and a kernel size of `3x3`. This convolutional layer should be followed by a ReLU activation function.
# * Then add an average pooling layer `torch.nn.AvgPool2d(...)` with a pooling kernel size of `2x2`.
# * Add another convolutional layer with `10` as the output channel number and `3x3` as the kernel size. This convolutional layer is also followed by a ReLU function.
# * Add another average pooling layer with the kernel size of `2x2`.
# * Flatten the output of the pooling layer using `torch.nn.Flatten()`.
# * Add a fully connected layer with `30` as the output channel number, with a ReLU activation function.
# * Finally, add another fully connected layer without activation function. Remember, the number of output units must match the dimension of the target data, which is 1.

# %%
"""TASK 1b.1.1: CREATE THETA MODEL HERE"""


# YOUR CODE HERE
class CNNTheta(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.relu1 = nn.ReLU()
        self.avg_pool1 = nn.AvgPool2d(2)
        self.conv2 = nn.Conv2d(32, 10, 3)
        self.relu2 = nn.ReLU()
        self.avg_pool2 = nn.AvgPool2d(2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(160, 30)
        self.relu3 = nn.ReLU()
        self.linear2 = nn.Linear(30, 1)

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.avg_pool1(x)
        
        x = self.relu2(self.conv2(x))
        x = self.avg_pool2(x)
        
        x = self.flatten(x)
        x = self.relu3(self.linear1(x))
        
        x = self.linear2(x)
        return x
        
"""TASK 1b.1.1: END"""

model_theta = CNNTheta()
total_params_theta = sum(p.numel() for p in model_theta.parameters())
print("Total number of trainable model parameters: ", total_params_theta)
# Out:
# Total number of trainable model parameters:  8071

# %% [markdown]
# ### Tasb 1b.1.2 - Train the model (4 points)
# Now that the model is defined, we can train it using the training dataset. Train the model for 50 epochs with the training data `train_loader`. Tune the learning rate in the optimizer to give the best performance on the validation and test set over the 50 epochs. For each training loop, it would be useful to test the model performance on the validation set to see if it is overfitting the training data or can generalize well. Do this 3 times and use the validation dataset `val_loader` with the function `evaluate_model` to get the validation result.
#
# **Hints:**
# - When we iterate over the training set, we use `(x, theta, _)` or something similar where `_` is used to ignore `trig`.
# - Reduce the number of epochs and lower the number of runs to `1` while getting your model working and setting the optimal learning rate.
# - Try varying the learning rate in the `1e-1` to `1e-5` range.

# %%
# set the number of runs (i.e., different random seeds)
num_runs = 3  # Change to 1 until you get it to work once
# number of epochs we train each model for
num_epochs = 50

# %%
if not AUTOGRADING:
    """TASK 1b.1.2: TRAIN MODEL HERE"""
    for run in range(num_runs):
        print(f"Starting run {run}")
        # set new random seed
        manual_seed(seed=run)
        # this code reinitializes the parameters of the model on each loop
        model_theta = CNNTheta()

        # define the optimizer
        optimizer = torch.optim.SGD(model_theta.parameters(), lr=8e-4)

        # YOUR CODE HERE
        for epoch in range(num_epochs):
            model_theta.train()
            running_loss = 0.0
            for x, theta, _ in train_loader:
                optimizer.zero_grad()
                theta_hat = model_theta(x)
                loss = loss_fn(theta_hat.squeeze(1), theta)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

            val_loss, val_error = evaluate_model(model_theta, val_loader, model_type="theta")
            avg_train_loss = running_loss / len(train_loader)
            print(
                f"Epoch {epoch+1}/{num_epochs} | train_loss={avg_train_loss:.4f} | "
                f"val_loss={val_loss:.4f} | val_error={val_error:.4f} rad"
            )
        
        run_test_loss, run_test_error = evaluate_model(
            model_theta, test_loader, model_type="theta"
        )
        print(
            f"Run {run} finished with a test loss of {run_test_loss:.4} rad^2 and a mean test error of {run_test_error:.4} rad."
        )

        # save the model
        torch.save(
            model_theta.state_dict(),
            STATEDICTS_DIR / f"task_1b_theta_model_run-{run}.pth",
            _use_new_zipfile_serialization=False,
        )
    """TASK 1.1.2: END"""
# Out:
# Starting run 0
# Epoch 1/50 | train_loss=8.9792 | val_loss=3.3646 | val_error=1.5807 rad
# Epoch 2/50 | train_loss=3.1942 | val_loss=3.2699 | val_error=1.5616 rad
# Epoch 3/50 | train_loss=3.1561 | val_loss=3.1666 | val_error=1.5360 rad
# Epoch 4/50 | train_loss=3.1284 | val_loss=3.1627 | val_error=1.5353 rad
# Epoch 5/50 | train_loss=3.1096 | val_loss=3.2072 | val_error=1.5445 rad
# Epoch 6/50 | train_loss=3.0758 | val_loss=3.1615 | val_error=1.5334 rad
# Epoch 7/50 | train_loss=3.0607 | val_loss=3.2076 | val_error=1.5408 rad
# Epoch 8/50 | train_loss=3.0329 | val_loss=3.0441 | val_error=1.4988 rad
# Epoch 9/50 | train_loss=2.9954 | val_loss=3.0370 | val_error=1.4991 rad
# Epoch 10/50 | train_loss=3.0068 | val_loss=3.0217 | val_error=1.4859 rad
# Epoch 11/50 | train_loss=2.9856 | val_loss=2.9610 | val_error=1.4762 rad
# Epoch 12/50 | train_loss=2.9268 | val_loss=3.0452 | val_error=1.4951 rad
# Epoch 13/50 | train_loss=2.8957 | val_loss=2.8882 | val_error=1.4549 rad
# Epoch 14/50 | train_loss=2.8713 | val_loss=2.8914 | val_error=1.4540 rad
# Epoch 15/50 | train_loss=2.7834 | val_loss=2.7649 | val_error=1.4173 rad
# Epoch 16/50 | train_loss=2.7599 | val_loss=2.6798 | val_error=1.3900 rad
# Epoch 17/50 | train_loss=2.6265 | val_loss=2.6817 | val_error=1.3819 rad
# Epoch 18/50 | train_loss=2.5506 | val_loss=2.4690 | val_error=1.3244 rad
# Epoch 19/50 | train_loss=2.3878 | val_loss=2.3355 | val_error=1.2773 rad
# Epoch 20/50 | train_loss=2.2118 | val_loss=2.2643 | val_error=1.2488 rad
# Epoch 21/50 | train_loss=2.0075 | val_loss=1.7997 | val_error=1.0872 rad
# Epoch 22/50 | train_loss=1.7386 | val_loss=1.4812 | val_error=0.9557 rad
# Epoch 23/50 | train_loss=1.4011 | val_loss=1.1584 | val_error=0.7798 rad
# Epoch 24/50 | train_loss=1.2420 | val_loss=1.0354 | val_error=0.7640 rad
# Epoch 25/50 | train_loss=1.1068 | val_loss=1.1530 | val_error=0.8466 rad
# Epoch 26/50 | train_loss=1.2846 | val_loss=1.0618 | val_error=0.8229 rad
# Epoch 27/50 | train_loss=1.0252 | val_loss=3.8220 | val_error=1.7134 rad
# Epoch 28/50 | train_loss=1.0531 | val_loss=0.6166 | val_error=0.4857 rad
# Epoch 29/50 | train_loss=1.1795 | val_loss=1.2207 | val_error=0.9663 rad
# Epoch 30/50 | train_loss=0.9072 | val_loss=0.6565 | val_error=0.4762 rad
# Epoch 31/50 | train_loss=0.9025 | val_loss=0.4981 | val_error=0.3521 rad
# Epoch 32/50 | train_loss=0.7890 | val_loss=0.6281 | val_error=0.5848 rad
# Epoch 33/50 | train_loss=0.8415 | val_loss=0.4847 | val_error=0.3660 rad
# Epoch 34/50 | train_loss=0.7213 | val_loss=0.5131 | val_error=0.4645 rad
# Epoch 35/50 | train_loss=0.6425 | val_loss=0.4336 | val_error=0.3104 rad
# Epoch 36/50 | train_loss=0.6868 | val_loss=0.4420 | val_error=0.3725 rad
# Epoch 37/50 | train_loss=0.5897 | val_loss=0.4435 | val_error=0.3888 rad
# Epoch 38/50 | train_loss=0.7004 | val_loss=0.3979 | val_error=0.2899 rad
# Epoch 39/50 | train_loss=0.5703 | val_loss=0.4769 | val_error=0.4433 rad
# Epoch 40/50 | train_loss=0.5986 | val_loss=2.9520 | val_error=1.6402 rad
# Epoch 41/50 | train_loss=0.6700 | val_loss=0.5184 | val_error=0.4929 rad
# Epoch 42/50 | train_loss=0.6354 | val_loss=0.3801 | val_error=0.3146 rad
# Epoch 43/50 | train_loss=0.5845 | val_loss=0.7914 | val_error=0.7104 rad
# Epoch 44/50 | train_loss=0.4468 | val_loss=0.3836 | val_error=0.3439 rad
# Epoch 45/50 | train_loss=0.4839 | val_loss=0.3693 | val_error=0.3346 rad
# Epoch 46/50 | train_loss=0.4574 | val_loss=0.4206 | val_error=0.4130 rad
# Epoch 47/50 | train_loss=0.5808 | val_loss=0.4430 | val_error=0.4406 rad
# Epoch 48/50 | train_loss=0.4525 | val_loss=0.7011 | val_error=0.6698 rad
# Epoch 49/50 | train_loss=0.4331 | val_loss=0.3246 | val_error=0.2592 rad
# Epoch 50/50 | train_loss=0.4148 | val_loss=0.3182 | val_error=0.2376 rad
# Run 0 finished with a test loss of 0.4131 rad^2 and a mean test error of 0.2776 rad.
# Starting run 1
# Epoch 1/50 | train_loss=12.2474 | val_loss=11.4591 | val_error=2.8820 rad
# Epoch 2/50 | train_loss=5.6020 | val_loss=3.2003 | val_error=1.5460 rad
# Epoch 3/50 | train_loss=3.1269 | val_loss=3.1483 | val_error=1.5297 rad
# Epoch 4/50 | train_loss=3.1060 | val_loss=3.1762 | val_error=1.5381 rad
# Epoch 5/50 | train_loss=3.0702 | val_loss=3.1159 | val_error=1.5218 rad
# Epoch 6/50 | train_loss=3.0897 | val_loss=3.0916 | val_error=1.5148 rad
# Epoch 7/50 | train_loss=3.0311 | val_loss=3.0676 | val_error=1.4991 rad
# Epoch 8/50 | train_loss=3.0052 | val_loss=3.0757 | val_error=1.5072 rad
# Epoch 9/50 | train_loss=2.9449 | val_loss=2.9526 | val_error=1.4723 rad
# Epoch 10/50 | train_loss=2.9236 | val_loss=2.9380 | val_error=1.4686 rad
# Epoch 11/50 | train_loss=2.8757 | val_loss=2.8962 | val_error=1.4550 rad
# Epoch 12/50 | train_loss=2.8078 | val_loss=2.8035 | val_error=1.4272 rad
# Epoch 13/50 | train_loss=2.7036 | val_loss=2.7040 | val_error=1.3959 rad
# Epoch 14/50 | train_loss=2.6088 | val_loss=2.5492 | val_error=1.3461 rad
# Epoch 15/50 | train_loss=2.4463 | val_loss=2.3780 | val_error=1.2898 rad
# Epoch 16/50 | train_loss=2.2969 | val_loss=2.2078 | val_error=1.2342 rad
# Epoch 17/50 | train_loss=2.0832 | val_loss=1.9045 | val_error=1.1235 rad
# Epoch 18/50 | train_loss=1.8633 | val_loss=1.6398 | val_error=1.0283 rad
# Epoch 19/50 | train_loss=1.5077 | val_loss=1.4421 | val_error=0.8847 rad
# Epoch 20/50 | train_loss=1.6400 | val_loss=1.0997 | val_error=0.7740 rad
# Epoch 21/50 | train_loss=1.6024 | val_loss=1.1699 | val_error=0.8468 rad
# Epoch 22/50 | train_loss=1.3919 | val_loss=5.3134 | val_error=2.0552 rad
# Epoch 23/50 | train_loss=1.3156 | val_loss=1.1019 | val_error=0.8474 rad
# Epoch 24/50 | train_loss=1.2456 | val_loss=0.9108 | val_error=0.6737 rad
# Epoch 25/50 | train_loss=1.2073 | val_loss=1.1876 | val_error=0.9311 rad
# Epoch 26/50 | train_loss=1.3601 | val_loss=0.6746 | val_error=0.4651 rad
# Epoch 27/50 | train_loss=0.9323 | val_loss=1.0024 | val_error=0.7821 rad
# Epoch 28/50 | train_loss=0.7651 | val_loss=0.8680 | val_error=0.7626 rad
# Epoch 29/50 | train_loss=1.0712 | val_loss=3.7676 | val_error=1.7490 rad
# Epoch 30/50 | train_loss=0.7892 | val_loss=0.6741 | val_error=0.5782 rad
# Epoch 31/50 | train_loss=0.6691 | val_loss=0.6794 | val_error=0.5954 rad
# Epoch 32/50 | train_loss=0.7668 | val_loss=2.1829 | val_error=1.3884 rad
# Epoch 33/50 | train_loss=0.8390 | val_loss=0.4804 | val_error=0.3547 rad
# Epoch 34/50 | train_loss=0.7203 | val_loss=0.5742 | val_error=0.4634 rad
# Epoch 35/50 | train_loss=0.6950 | val_loss=0.5724 | val_error=0.5516 rad
# Epoch 36/50 | train_loss=0.7003 | val_loss=0.4609 | val_error=0.3996 rad
# Epoch 37/50 | train_loss=0.5475 | val_loss=0.4104 | val_error=0.2812 rad
# Epoch 38/50 | train_loss=0.5995 | val_loss=0.4341 | val_error=0.3755 rad
# Epoch 39/50 | train_loss=0.5757 | val_loss=1.3339 | val_error=1.0124 rad
# Epoch 40/50 | train_loss=0.5520 | val_loss=0.3836 | val_error=0.2878 rad
# Epoch 41/50 | train_loss=0.5629 | val_loss=0.3848 | val_error=0.2642 rad
# Epoch 42/50 | train_loss=0.5722 | val_loss=0.3867 | val_error=0.2962 rad
# Epoch 43/50 | train_loss=0.5380 | val_loss=0.3752 | val_error=0.3111 rad
# Epoch 44/50 | train_loss=0.5011 | val_loss=0.3590 | val_error=0.2492 rad
# Epoch 45/50 | train_loss=0.4805 | val_loss=0.3712 | val_error=0.2702 rad
# Epoch 46/50 | train_loss=0.4782 | val_loss=1.0045 | val_error=0.8566 rad
# Epoch 47/50 | train_loss=0.4627 | val_loss=0.3514 | val_error=0.2864 rad
# Epoch 48/50 | train_loss=0.4267 | val_loss=0.3305 | val_error=0.2512 rad
# Epoch 49/50 | train_loss=0.4460 | val_loss=0.3826 | val_error=0.4030 rad
# Epoch 50/50 | train_loss=0.4466 | val_loss=0.3352 | val_error=0.3096 rad
# Run 1 finished with a test loss of 0.4399 rad^2 and a mean test error of 0.3467 rad.
# Starting run 2
# Epoch 1/50 | train_loss=11.1127 | val_loss=4.8359 | val_error=1.8161 rad
# Epoch 2/50 | train_loss=3.2462 | val_loss=3.1970 | val_error=1.5463 rad
# Epoch 3/50 | train_loss=3.1331 | val_loss=3.2748 | val_error=1.5600 rad
# Epoch 4/50 | train_loss=3.0810 | val_loss=3.1117 | val_error=1.5180 rad
# Epoch 5/50 | train_loss=3.0722 | val_loss=3.1123 | val_error=1.5223 rad
# Epoch 6/50 | train_loss=3.0500 | val_loss=3.1139 | val_error=1.5214 rad
# Epoch 7/50 | train_loss=3.0488 | val_loss=3.0682 | val_error=1.5089 rad
# Epoch 8/50 | train_loss=3.0193 | val_loss=2.9950 | val_error=1.4880 rad
# Epoch 9/50 | train_loss=2.9545 | val_loss=2.9851 | val_error=1.4849 rad
# Epoch 10/50 | train_loss=2.9132 | val_loss=2.9302 | val_error=1.4687 rad
# Epoch 11/50 | train_loss=2.8834 | val_loss=2.9372 | val_error=1.4680 rad
# Epoch 12/50 | train_loss=2.8374 | val_loss=2.8889 | val_error=1.4525 rad
# Epoch 13/50 | train_loss=2.7622 | val_loss=2.7740 | val_error=1.4203 rad
# Epoch 14/50 | train_loss=2.6947 | val_loss=2.6932 | val_error=1.3945 rad
# Epoch 15/50 | train_loss=2.5964 | val_loss=2.6770 | val_error=1.3803 rad
# Epoch 16/50 | train_loss=2.5195 | val_loss=2.5599 | val_error=1.3488 rad
# Epoch 17/50 | train_loss=2.3436 | val_loss=2.2353 | val_error=1.2463 rad
# Epoch 18/50 | train_loss=2.1436 | val_loss=2.0022 | val_error=1.1651 rad
# Epoch 19/50 | train_loss=1.8989 | val_loss=1.8005 | val_error=1.0641 rad
# Epoch 20/50 | train_loss=1.6025 | val_loss=1.9081 | val_error=1.0743 rad
# Epoch 21/50 | train_loss=1.3204 | val_loss=1.0988 | val_error=0.7416 rad
# Epoch 22/50 | train_loss=1.0652 | val_loss=0.9775 | val_error=0.6629 rad
# Epoch 23/50 | train_loss=0.9300 | val_loss=1.0833 | val_error=0.7911 rad
# Epoch 24/50 | train_loss=1.1881 | val_loss=1.4667 | val_error=1.0716 rad
# Epoch 25/50 | train_loss=0.9346 | val_loss=1.0766 | val_error=0.8848 rad
# Epoch 26/50 | train_loss=0.7672 | val_loss=0.5389 | val_error=0.4151 rad
# Epoch 27/50 | train_loss=0.8817 | val_loss=0.6507 | val_error=0.5945 rad
# Epoch 28/50 | train_loss=0.8184 | val_loss=0.4842 | val_error=0.3285 rad
# Epoch 29/50 | train_loss=0.7055 | val_loss=0.5504 | val_error=0.4624 rad
# Epoch 30/50 | train_loss=0.6235 | val_loss=0.4371 | val_error=0.3148 rad
# Epoch 31/50 | train_loss=0.6150 | val_loss=0.4522 | val_error=0.3292 rad
# Epoch 32/50 | train_loss=0.6940 | val_loss=0.4189 | val_error=0.3050 rad
# Epoch 33/50 | train_loss=0.7088 | val_loss=0.4062 | val_error=0.3010 rad
# Epoch 34/50 | train_loss=0.5924 | val_loss=0.4613 | val_error=0.4099 rad
# Epoch 35/50 | train_loss=0.5774 | val_loss=0.3912 | val_error=0.3025 rad
# Epoch 36/50 | train_loss=0.5274 | val_loss=0.7596 | val_error=0.7257 rad
# Epoch 37/50 | train_loss=0.6928 | val_loss=0.4288 | val_error=0.3715 rad
# Epoch 38/50 | train_loss=0.5271 | val_loss=1.0784 | val_error=0.8680 rad
# Epoch 39/50 | train_loss=0.5400 | val_loss=0.4313 | val_error=0.4297 rad
# Epoch 40/50 | train_loss=0.5126 | val_loss=0.3498 | val_error=0.2473 rad
# Epoch 41/50 | train_loss=0.5383 | val_loss=0.3773 | val_error=0.3355 rad
# Epoch 42/50 | train_loss=0.5183 | val_loss=1.3123 | val_error=1.0343 rad
# Epoch 43/50 | train_loss=0.5524 | val_loss=0.3742 | val_error=0.3587 rad
# Epoch 44/50 | train_loss=0.4633 | val_loss=0.4263 | val_error=0.4504 rad
# Epoch 45/50 | train_loss=0.4700 | val_loss=0.3794 | val_error=0.3679 rad
# Epoch 46/50 | train_loss=0.4522 | val_loss=0.4772 | val_error=0.5272 rad
# Epoch 47/50 | train_loss=0.4922 | val_loss=0.3223 | val_error=0.2813 rad
# Epoch 48/50 | train_loss=0.4231 | val_loss=0.4946 | val_error=0.5057 rad
# Epoch 49/50 | train_loss=0.4257 | val_loss=0.3018 | val_error=0.2474 rad
# Epoch 50/50 | train_loss=0.4073 | val_loss=0.4051 | val_error=0.4443 rad
# Run 2 finished with a test loss of 0.5127 rad^2 and a mean test error of 0.4723 rad.

# %% [markdown]
# Evaluate the final result on the `test_loader` using the function `evaluate_model`. The `model_type` is `theta` in this situation.

# %%
# evaluate the theta model on the test set
test_error_across_runs_theta = np.zeros((num_runs,))
for run in range(num_runs):
    model_theta.load_state_dict(
        torch.load(STATEDICTS_DIR / f"task_1b_theta_model_run-{run}.pth")
    )
    run_test_loss, run_test_error = evaluate_model(
        model_theta, test_loader, model_type="theta"
    )
    test_error_across_runs_theta[run] = run_test_error
print(
    f"Prediction error of theta model across runs: {np.mean(test_error_across_runs_theta):.4} += {np.std(test_error_across_runs_theta):.4} rad."
)
# Out:
# Prediction error of theta model across runs: 0.3656 += 0.08059 rad.

# %% [markdown]
# ### Tasb 1b.1.3 - Analyse model performance (2 points)
# Evaluate the trained model's accuracy by examining the average error in the link angle prediction. Please analyze the training loss curve: does the training loss decrease step by step? (1 point)

# %% [markdown]
# The model achieves a very high 0.3656 +- 0.08059 rad error in link angle prediction. The training loss does not monotonically decrease step by step but there is a clear downward trend, it starts at around 10 and decreases to 0.4 across all three runs. This is to be expected because we are doing mini-batch SGD, where each batch is a noisy estimate of the true gradient. The validation loss shows higher varience across epochs, jumping from values between 0.4 and 1.0, indicating a poor convergence. The validation error follows a similar spiky trend, showing that the model has difficulties in converging to a good generalization.

# %% [markdown]
# We always use a separate test dataset to evaluate a trained model. What is the reason for this? (1 point)

# %% [markdown]
# In Machine Learning we have three dataset splits: training, validation and testing. The validation dataset is used to check for convergence during training, and to evaluate the quality and effect of the chosen hyperparameters. The test dataset is used to perform the final evaluation of the model. The reason for keeping it separate during the training process is to obtain a truly unbiased estimate of a model's generalization performance on truly unseen data. If the testing set were to be used during training (even just for monitoring) like the validation set is used, the user might implicitly tune hyperparameters to improve the performance, which would cause the reported accuracy to overestiamte the model's performance, on new unseen data.

# %% [markdown]
# ## Task 1b.2 - Indirectly predict the angle (10.5 points)
# We are going to improve the accuracy by pre-processing the target data. Specifically, we will create a model $M_{trig}$ that learns to predict $\sin(\theta)$ and $\cos(\theta)$ for the pendulum instead of directly predicting $\theta$. Then, we can use the inverse tangent function to retrieve an estimate of $\theta$ for both links.
#
# *Note:* In practice you would use the `atan2` implementation, as the regular arctangent only covers $[-\frac{1}{2}\pi, \frac{1}{2}\pi]$} $\theta=\arctan(\frac{\sin(\theta)}{\cos(\theta)})$

# %% [markdown]
# ### Task 1b.2.1 - Create the model (3.5 points)
# Copy the model you created in Task 1.1. Change the number of hidden units of the final layer from 1 to 2. We do so because we now want to predict two outputs ($\sin(\theta)$, $\cos(\theta)$) for each sample. The total number of the model parameters should increase slightly compared to Task 1.1. _**Optional question:** Why does the number of model parameters increase?_

# %%
"""TASK 1b.2.1: CREATE TRIGONOMETRIC MODEL HERE"""


# YOUR CODE HERE
class CNNTrig(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.relu1 = nn.ReLU()
        self.avg_pool1 = nn.AvgPool2d(2)
        self.conv2 = nn.Conv2d(32, 10, 3)
        self.relu2 = nn.ReLU()
        self.avg_pool2 = nn.AvgPool2d(2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(160, 30)
        self.relu3 = nn.ReLU()
        self.linear2 = nn.Linear(30, 2)

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.avg_pool1(x)
        
        x = self.relu2(self.conv2(x))
        x = self.avg_pool2(x)
        
        x = self.flatten(x)
        x = self.relu3(self.linear1(x))
        
        x = self.linear2(x)
        return x
"""TASK 1b.2.1: END"""

model_trig = CNNTrig()
total_params_trig = sum(p.numel() for p in model_trig.parameters())
print("total number of model parameters: ", total_params_trig)
# Out:
# total number of model parameters:  8102

# %% [markdown]
# ### Task 1b.2.2 - Train the model (4 points)
# Now train a model with the same training hyperparameters as in task 1.1 but using the the trigonometric labels. When dealing with the return value of the `train_loader,` be careful to make sure that the output is the $[\sin(\theta)$, $\cos(\theta)]$ instead of $\theta$. Tune the learning rate in the optimizer to give the best performance on the validation and test set over the 50 epochs. Do this 3 times like the previous task.
#
# **Hint:**
# - We utilize the third instead of the second item in the tuple returned by the dataloader. Therefore, when we iterate over the training set, we use `(x, _, trig)` where `_` is applied to ignore `theta`. Here, `trig` is a tensor containing $\sin$ value and $\cos$ value
# - Reduce the number of epochs and lower the number of runs to `1` while getting your model working.
# - Try in the range `1e-1` to `1e-5` for the learning rate

# %%
# set the number of runs (i.e., different random seeds)
num_runs = 3  # Change to 1 until you get it to work once
# number of epochs we train each model for
num_epochs = 50

# %%
if not AUTOGRADING:
    """TASK 1b.2.2: TRAIN TRIGONOMETRIC MODEL HERE"""
    for run in range(num_runs):
        print(f"Starting run {run}")
        # set new random seed
        manual_seed(seed=run)
        # this code reinitializes the parameters of the model on each loop
        model_trig = CNNTrig()

        # define the optimizer
        optimizer = torch.optim.SGD(model_trig.parameters(), lr=1e-2)

        # YOUR CODE HERE
        for epoch in range(num_epochs):
            model_trig.train()
            running_loss = 0.0
            for x, _, trig in train_loader:
                optimizer.zero_grad()
                trig_hat = model_trig(x)
                # angle_hat = torch.atan2(trig_hat[:, 0], trig_hat[:, 1])
                # angle = torch.atan2(trig[:, 0], trig[:, 1])
                
                loss = loss_fn(trig_hat, trig)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

            val_loss, val_error = evaluate_model(model_trig, val_loader, model_type="trig")
            avg_train_loss = running_loss / len(train_loader)
            print(
                f"Epoch {epoch+1}/{num_epochs} | train_loss={avg_train_loss:.4f} | "
                f"val_loss={val_loss:.4f} | val_error={val_error:.4f} rad"
            )
                    
        run_test_loss, run_test_error = evaluate_model(
            model_trig, test_loader, model_type="trig"
        )
        print(
            f"Run {run} finished with a test loss of {run_test_loss:.4} and a mean test error of {run_test_error:.4} rad."
        )

        # save the model
        torch.save(
            model_trig.state_dict(),
            STATEDICTS_DIR / f"task_1b_trig_model_run-{run}.pth",
            _use_new_zipfile_serialization=False,
        )
    """TASK 1b.2.2: END"""
# Out:
# Starting run 0
# Epoch 1/50 | train_loss=0.5001 | val_loss=0.4968 | val_error=2.4784 rad
# Epoch 2/50 | train_loss=0.4949 | val_loss=0.4948 | val_error=2.8238 rad
# Epoch 3/50 | train_loss=0.4926 | val_loss=0.4914 | val_error=1.8491 rad
# Epoch 4/50 | train_loss=0.4895 | val_loss=0.4879 | val_error=1.4175 rad
# Epoch 5/50 | train_loss=0.4852 | val_loss=0.4829 | val_error=1.7314 rad
# Epoch 6/50 | train_loss=0.4789 | val_loss=0.4762 | val_error=2.7072 rad
# Epoch 7/50 | train_loss=0.4679 | val_loss=0.4743 | val_error=2.3225 rad
# Epoch 8/50 | train_loss=0.4502 | val_loss=0.4384 | val_error=1.2648 rad
# Epoch 9/50 | train_loss=0.4145 | val_loss=0.4337 | val_error=2.5292 rad
# Epoch 10/50 | train_loss=0.3520 | val_loss=0.3007 | val_error=0.4206 rad
# Epoch 11/50 | train_loss=0.2892 | val_loss=0.3310 | val_error=1.3957 rad
# Epoch 12/50 | train_loss=0.2470 | val_loss=0.1420 | val_error=0.3900 rad
# Epoch 13/50 | train_loss=0.1953 | val_loss=0.2646 | val_error=0.8725 rad
# Epoch 14/50 | train_loss=0.1443 | val_loss=0.2130 | val_error=0.9679 rad
# Epoch 15/50 | train_loss=0.0804 | val_loss=0.0138 | val_error=0.1062 rad
# Epoch 16/50 | train_loss=0.0483 | val_loss=0.0570 | val_error=0.4757 rad
# Epoch 17/50 | train_loss=0.0221 | val_loss=0.0034 | val_error=0.0389 rad
# Epoch 18/50 | train_loss=0.0189 | val_loss=0.0144 | val_error=0.3325 rad
# Epoch 19/50 | train_loss=0.0086 | val_loss=0.0027 | val_error=0.0885 rad
# Epoch 20/50 | train_loss=0.0044 | val_loss=0.0019 | val_error=0.1017 rad
# Epoch 21/50 | train_loss=0.0044 | val_loss=0.0097 | val_error=0.2311 rad
# Epoch 22/50 | train_loss=0.0030 | val_loss=0.0052 | val_error=0.2052 rad
# Epoch 23/50 | train_loss=0.0032 | val_loss=0.0007 | val_error=0.0421 rad
# Epoch 24/50 | train_loss=0.0018 | val_loss=0.0031 | val_error=0.0931 rad
# Epoch 25/50 | train_loss=0.0015 | val_loss=0.0044 | val_error=0.2171 rad
# Epoch 26/50 | train_loss=0.0025 | val_loss=0.0024 | val_error=0.0525 rad
# Epoch 27/50 | train_loss=0.0010 | val_loss=0.0005 | val_error=0.0718 rad
# Epoch 28/50 | train_loss=0.0011 | val_loss=0.0005 | val_error=0.0648 rad
# Epoch 29/50 | train_loss=0.0014 | val_loss=0.0014 | val_error=0.0599 rad
# Epoch 30/50 | train_loss=0.0010 | val_loss=0.0005 | val_error=0.0801 rad
# Epoch 31/50 | train_loss=0.0017 | val_loss=0.0006 | val_error=0.0256 rad
# Epoch 32/50 | train_loss=0.0006 | val_loss=0.0014 | val_error=0.1248 rad
# Epoch 33/50 | train_loss=0.0010 | val_loss=0.0007 | val_error=0.0462 rad
# Epoch 34/50 | train_loss=0.0007 | val_loss=0.0011 | val_error=0.1196 rad
# Epoch 35/50 | train_loss=0.0009 | val_loss=0.0017 | val_error=0.1286 rad
# Epoch 36/50 | train_loss=0.0008 | val_loss=0.0006 | val_error=0.0591 rad
# Epoch 37/50 | train_loss=0.0004 | val_loss=0.0007 | val_error=0.0379 rad
# Epoch 38/50 | train_loss=0.0009 | val_loss=0.0006 | val_error=0.0361 rad
# Epoch 39/50 | train_loss=0.0007 | val_loss=0.0004 | val_error=0.0221 rad
# Epoch 40/50 | train_loss=0.0005 | val_loss=0.0004 | val_error=0.0817 rad
# Epoch 41/50 | train_loss=0.0008 | val_loss=0.0014 | val_error=0.0683 rad
# Epoch 42/50 | train_loss=0.0008 | val_loss=0.0018 | val_error=0.0640 rad
# Epoch 43/50 | train_loss=0.0010 | val_loss=0.0012 | val_error=0.0570 rad
# Epoch 44/50 | train_loss=0.0006 | val_loss=0.0007 | val_error=0.0894 rad
# Epoch 45/50 | train_loss=0.0004 | val_loss=0.0002 | val_error=0.0514 rad
# Epoch 46/50 | train_loss=0.0005 | val_loss=0.0016 | val_error=0.0616 rad
# Epoch 47/50 | train_loss=0.0009 | val_loss=0.0004 | val_error=0.0326 rad
# Epoch 48/50 | train_loss=0.0007 | val_loss=0.0005 | val_error=0.0869 rad
# Epoch 49/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0641 rad
# Epoch 50/50 | train_loss=0.0003 | val_loss=0.0002 | val_error=0.0607 rad
# Run 0 finished with a test loss of 0.0002219 and a mean test error of 0.02692 rad.
# Starting run 1
# Epoch 1/50 | train_loss=0.5018 | val_loss=0.4992 | val_error=2.8520 rad
# Epoch 2/50 | train_loss=0.4980 | val_loss=0.4976 | val_error=1.9762 rad
# Epoch 3/50 | train_loss=0.4967 | val_loss=0.4964 | val_error=1.6942 rad
# Epoch 4/50 | train_loss=0.4956 | val_loss=0.4947 | val_error=2.7002 rad
# Epoch 5/50 | train_loss=0.4938 | val_loss=0.4929 | val_error=2.2757 rad
# Epoch 6/50 | train_loss=0.4918 | val_loss=0.4911 | val_error=2.2028 rad
# Epoch 7/50 | train_loss=0.4894 | val_loss=0.4873 | val_error=0.7754 rad
# Epoch 8/50 | train_loss=0.4853 | val_loss=0.4828 | val_error=0.8321 rad
# Epoch 9/50 | train_loss=0.4799 | val_loss=0.4752 | val_error=0.4835 rad
# Epoch 10/50 | train_loss=0.4696 | val_loss=0.4623 | val_error=0.7468 rad
# Epoch 11/50 | train_loss=0.4526 | val_loss=0.4402 | val_error=0.8425 rad
# Epoch 12/50 | train_loss=0.4203 | val_loss=0.3966 | val_error=0.9389 rad
# Epoch 13/50 | train_loss=0.3611 | val_loss=0.4011 | val_error=2.0365 rad
# Epoch 14/50 | train_loss=0.3059 | val_loss=0.5004 | val_error=2.1106 rad
# Epoch 15/50 | train_loss=0.2426 | val_loss=0.2248 | val_error=0.7651 rad
# Epoch 16/50 | train_loss=0.2022 | val_loss=0.1493 | val_error=0.4473 rad
# Epoch 17/50 | train_loss=0.1476 | val_loss=0.1000 | val_error=0.6893 rad
# Epoch 18/50 | train_loss=0.0980 | val_loss=0.0649 | val_error=0.5340 rad
# Epoch 19/50 | train_loss=0.0694 | val_loss=0.0092 | val_error=0.1346 rad
# Epoch 20/50 | train_loss=0.0392 | val_loss=0.0352 | val_error=0.4646 rad
# Epoch 21/50 | train_loss=0.0305 | val_loss=0.0064 | val_error=0.1877 rad
# Epoch 22/50 | train_loss=0.0135 | val_loss=0.0087 | val_error=0.2838 rad
# Epoch 23/50 | train_loss=0.0110 | val_loss=0.0061 | val_error=0.1020 rad
# Epoch 24/50 | train_loss=0.0067 | val_loss=0.0028 | val_error=0.1074 rad
# Epoch 25/50 | train_loss=0.0053 | val_loss=0.0030 | val_error=0.0740 rad
# Epoch 26/50 | train_loss=0.0037 | val_loss=0.0054 | val_error=0.1707 rad
# Epoch 27/50 | train_loss=0.0045 | val_loss=0.0031 | val_error=0.1408 rad
# Epoch 28/50 | train_loss=0.0019 | val_loss=0.0009 | val_error=0.0796 rad
# Epoch 29/50 | train_loss=0.0022 | val_loss=0.0074 | val_error=0.1267 rad
# Epoch 30/50 | train_loss=0.0016 | val_loss=0.0011 | val_error=0.0425 rad
# Epoch 31/50 | train_loss=0.0018 | val_loss=0.0029 | val_error=0.0848 rad
# Epoch 32/50 | train_loss=0.0022 | val_loss=0.0012 | val_error=0.0925 rad
# Epoch 33/50 | train_loss=0.0023 | val_loss=0.0009 | val_error=0.0393 rad
# Epoch 34/50 | train_loss=0.0010 | val_loss=0.0007 | val_error=0.0268 rad
# Epoch 35/50 | train_loss=0.0009 | val_loss=0.0009 | val_error=0.0494 rad
# Epoch 36/50 | train_loss=0.0008 | val_loss=0.0006 | val_error=0.0172 rad
# Epoch 37/50 | train_loss=0.0010 | val_loss=0.0005 | val_error=0.0151 rad
# Epoch 38/50 | train_loss=0.0006 | val_loss=0.0005 | val_error=0.0411 rad
# Epoch 39/50 | train_loss=0.0015 | val_loss=0.0005 | val_error=0.0405 rad
# Epoch 40/50 | train_loss=0.0009 | val_loss=0.0015 | val_error=0.0586 rad
# Epoch 41/50 | train_loss=0.0007 | val_loss=0.0005 | val_error=0.0267 rad
# Epoch 42/50 | train_loss=0.0007 | val_loss=0.0006 | val_error=0.0256 rad
# Epoch 43/50 | train_loss=0.0008 | val_loss=0.0015 | val_error=0.0601 rad
# Epoch 44/50 | train_loss=0.0007 | val_loss=0.0005 | val_error=0.0570 rad
# Epoch 45/50 | train_loss=0.0010 | val_loss=0.0004 | val_error=0.0216 rad
# Epoch 46/50 | train_loss=0.0008 | val_loss=0.0012 | val_error=0.0721 rad
# Epoch 47/50 | train_loss=0.0006 | val_loss=0.0005 | val_error=0.0310 rad
# Epoch 48/50 | train_loss=0.0005 | val_loss=0.0004 | val_error=0.0202 rad
# Epoch 49/50 | train_loss=0.0005 | val_loss=0.0007 | val_error=0.0747 rad
# Epoch 50/50 | train_loss=0.0005 | val_loss=0.0005 | val_error=0.0169 rad
# Run 1 finished with a test loss of 0.0005322 and a mean test error of 0.01741 rad.
# Starting run 2
# Epoch 1/50 | train_loss=0.5023 | val_loss=0.4985 | val_error=1.6653 rad
# Epoch 2/50 | train_loss=0.4982 | val_loss=0.4973 | val_error=2.1737 rad
# Epoch 3/50 | train_loss=0.4966 | val_loss=0.4960 | val_error=2.4378 rad
# Epoch 4/50 | train_loss=0.4949 | val_loss=0.4945 | val_error=2.1504 rad
# Epoch 5/50 | train_loss=0.4932 | val_loss=0.4924 | val_error=2.2648 rad
# Epoch 6/50 | train_loss=0.4909 | val_loss=0.4903 | val_error=1.7604 rad
# Epoch 7/50 | train_loss=0.4877 | val_loss=0.4861 | val_error=1.3226 rad
# Epoch 8/50 | train_loss=0.4832 | val_loss=0.4809 | val_error=2.0692 rad
# Epoch 9/50 | train_loss=0.4761 | val_loss=0.4718 | val_error=1.8979 rad
# Epoch 10/50 | train_loss=0.4648 | val_loss=0.4602 | val_error=2.3846 rad
# Epoch 11/50 | train_loss=0.4458 | val_loss=0.4376 | val_error=1.8346 rad
# Epoch 12/50 | train_loss=0.4112 | val_loss=0.3890 | val_error=1.1086 rad
# Epoch 13/50 | train_loss=0.3455 | val_loss=0.3658 | val_error=2.0185 rad
# Epoch 14/50 | train_loss=0.2460 | val_loss=0.2028 | val_error=0.4889 rad
# Epoch 15/50 | train_loss=0.2024 | val_loss=0.3444 | val_error=1.2952 rad
# Epoch 16/50 | train_loss=0.1372 | val_loss=0.0694 | val_error=0.4520 rad
# Epoch 17/50 | train_loss=0.0956 | val_loss=0.0548 | val_error=0.4674 rad
# Epoch 18/50 | train_loss=0.0474 | val_loss=0.0117 | val_error=0.1427 rad
# Epoch 19/50 | train_loss=0.0199 | val_loss=0.0545 | val_error=0.3040 rad
# Epoch 20/50 | train_loss=0.0120 | val_loss=0.0072 | val_error=0.1143 rad
# Epoch 21/50 | train_loss=0.0091 | val_loss=0.0018 | val_error=0.0483 rad
# Epoch 22/50 | train_loss=0.0027 | val_loss=0.0017 | val_error=0.0323 rad
# Epoch 23/50 | train_loss=0.0053 | val_loss=0.0050 | val_error=0.1405 rad
# Epoch 24/50 | train_loss=0.0044 | val_loss=0.0038 | val_error=0.1104 rad
# Epoch 25/50 | train_loss=0.0028 | val_loss=0.0070 | val_error=0.1823 rad
# Epoch 26/50 | train_loss=0.0023 | val_loss=0.0026 | val_error=0.1175 rad
# Epoch 27/50 | train_loss=0.0023 | val_loss=0.0029 | val_error=0.1370 rad
# Epoch 28/50 | train_loss=0.0010 | val_loss=0.0017 | val_error=0.1063 rad
# Epoch 29/50 | train_loss=0.0018 | val_loss=0.0014 | val_error=0.0558 rad
# Epoch 30/50 | train_loss=0.0007 | val_loss=0.0005 | val_error=0.0448 rad
# Epoch 31/50 | train_loss=0.0009 | val_loss=0.0014 | val_error=0.0789 rad
# Epoch 32/50 | train_loss=0.0012 | val_loss=0.0044 | val_error=0.1393 rad
# Epoch 33/50 | train_loss=0.0012 | val_loss=0.0018 | val_error=0.0656 rad
# Epoch 34/50 | train_loss=0.0014 | val_loss=0.0005 | val_error=0.0437 rad
# Epoch 35/50 | train_loss=0.0008 | val_loss=0.0007 | val_error=0.0497 rad
# Epoch 36/50 | train_loss=0.0007 | val_loss=0.0004 | val_error=0.0167 rad
# Epoch 37/50 | train_loss=0.0006 | val_loss=0.0006 | val_error=0.0294 rad
# Epoch 38/50 | train_loss=0.0004 | val_loss=0.0004 | val_error=0.0178 rad
# Epoch 39/50 | train_loss=0.0007 | val_loss=0.0007 | val_error=0.0655 rad
# Epoch 40/50 | train_loss=0.0006 | val_loss=0.0006 | val_error=0.0462 rad
# Epoch 41/50 | train_loss=0.0005 | val_loss=0.0007 | val_error=0.0317 rad
# Epoch 42/50 | train_loss=0.0004 | val_loss=0.0003 | val_error=0.0127 rad
# Epoch 43/50 | train_loss=0.0006 | val_loss=0.0004 | val_error=0.0425 rad
# Epoch 44/50 | train_loss=0.0004 | val_loss=0.0011 | val_error=0.0983 rad
# Epoch 45/50 | train_loss=0.0005 | val_loss=0.0008 | val_error=0.0263 rad
# Epoch 46/50 | train_loss=0.0005 | val_loss=0.0006 | val_error=0.0465 rad
# Epoch 47/50 | train_loss=0.0006 | val_loss=0.0004 | val_error=0.0242 rad
# Epoch 48/50 | train_loss=0.0006 | val_loss=0.0004 | val_error=0.0410 rad
# Epoch 49/50 | train_loss=0.0004 | val_loss=0.0007 | val_error=0.0403 rad
# Epoch 50/50 | train_loss=0.0004 | val_loss=0.0005 | val_error=0.0354 rad
# Run 2 finished with a test loss of 0.0004822 and a mean test error of 0.03568 rad.

# %% [markdown]
# Evaluate the final result on the `test_loader` using the function `evaluate_model`.

# %%
# evaluate the trig model on the test set
test_error_across_runs_trig = np.zeros((num_runs,))
for run in range(num_runs):
    model_trig.load_state_dict(
        torch.load(STATEDICTS_DIR / f"task_1b_trig_model_run-{run}.pth")
    )
    run_test_loss, run_test_error = evaluate_model(
        model_trig, test_loader, model_type="trig"
    )
    test_error_across_runs_trig[run] = run_test_error
print(
    f"Prediction error of trig model across runs: {np.mean(test_error_across_runs_trig):.4} += {np.std(test_error_across_runs_trig):.4} rad."
)
# Out:
# Prediction error of trig model across runs: 0.02667 += 0.007462 rad.

# %% [markdown]
# ### Task 1b.2.3 - Analyse model performance (3 points)

# %% [markdown]
# Analyse the model's training loss. Does your training loss decrease step by step? Do you find some magnitude difference between the training loss of $M_{trig}$ with the previous one of $M_θ$? Can you explain why they are different? (1 point)

# %% [markdown]
# The training loss of M_trig generally decreases (under the same mini-batch SGD noise), but the magnitude is significantly smaller than M_theta. M_trig already starts at a train loss of 0.5 (while the M_theta model was converging after 50 epochs to 0.4), and ends with a loss of 0.0004, making the relative magnitude between the two train losses 100x. The incredible improvement in performance is because M_trig predicts \[sin(theta), cos(theta)] which are bounded in \[-1, 1]. Predicting directly the theta over a range of several radians leads to much larger squared error values.
#
# The validation loss and errors also decrease consistently without showing the spiking behaviour seen during training M_theta. This proves that this way of learning is leads to much better generalization. The final prediction error of the trig model sits now at only 0.026 - 0.0074 rad.

# %% [markdown]
# Compare the prediction estimates for $M_{trig}$ with the plot for $M_θ$. Why does indirectly predicting the angle improve the prediction accuracy? (1 point)

# %% [markdown]
# Direct angle prediction suffers from a wrapping problem where angles near $+\pi$ and $-\pi$ are almost identical but numerically very far apart. The MSE penalizes these predictions near the boundary heavily. This makes the learning much more difficult and the loss landscape harder to optimize over, hence the spiking behaviour noticed in the validation loss during the M_theta training.
#
# In contrast, indirect prediction removes the discontinuity in the angle representation. By predicting sin(theta) and cost(theta), the output space is continous and smooth on the unit circle, and there are no discontinuities. The network is capable of learning much easier the expected mapping, reducing the training error significantly.

# %% [markdown]
# Why is it not sufficient to predict only sin(θ) and use its inverse θ = arcsin(sin(θ)) to get an estimate of the angle? (1 point)

# %% [markdown]
# Arcsin produces outputs only in $[-\pi/2, \pi/2]$, so two distinct angles (30, and 150 degrees) will produce the same value. This makes it impossible to uniqely recover values outside of that range. In other words, arcsin is not injective over the whole range that theta will take values in. By predicting also cos(theta) we have sufficient information to uniqely determine angle values on the full $[-\pi, \pi]$ range.
