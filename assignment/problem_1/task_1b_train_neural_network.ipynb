# %% [markdown]
# # RO47019: Intelligent Control Systems Practical Assignment
# * Period: 2025-2026, Q3
# * Course homepage: https://brightspace.tudelft.nl/d2l/home/775422
# * Instructor: Cosimo Della Santina (C.DellaSantina@tudelft.nl)
# * Teaching assistant: Mukil Saravanan (m.saravanan-1@student.tudelft.nl)
# * (c) TU Delft, 2026
#
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE` and remove `raise NotImplementedError()` afterwards. Moreover, if you see an empty cell, please **do not** delete it, instead run that cell as you would run all other cells. Finally, please **do not** add any extra cells to this notebook or change the existing cells unless you are explicitly asked to do so.
#
# Please fill in your name(s) and other required details below:

# %%
# Please fill in your names, student numbers, netID, and emails below.
STUDENT_1_NAME = "Andrei Simionescu"
STUDENT_1_STUDENT_NUMBER = "5459559"
STUDENT_1_NETID = "asimionescu"
STUDENT_1_EMAIL = "asimionescu@tudelft.nl"

# %%
# Note: this block is a check that you have filled in the above information.
# It will throw an AssertionError until all fields are filled
assert STUDENT_1_NAME != ""
assert STUDENT_1_STUDENT_NUMBER != ""
assert STUDENT_1_NETID != ""
assert STUDENT_1_EMAIL != ""

# %% [markdown]
# ### General announcements
#
# * Do *not* share your solutions (also after the course is finished), and do *not* copy solutions from others. By submitting your solutions, you claim that you alone are responsible for this code.
#
# * Please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. Please note that it is **not** allowed to post any code relating to solution attempts. If you do have a particular question that you want to ask directly, please use the scheduled Q&A hours to ask the TA or if not possible otherwise, send an email to the instructor or TA.
#
# * This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for you that you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.
#
# * This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook "uneditable" or "unremovable" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment.
#
# * Please note that the above mentioned _read-only_ protection only works in Jupyter Notebook, and it does not work if you open this notebook in another editor (e.g., VSCode, PyCharm, etc.). Therefore, we recommend that you only use Jupyter Notebook for this course. If you use any other editor, you may accidentally delete cells, modify the tests, etc., which would cause you to lose points.
#
# * If you edit a function that is imported in another notebook, you need to **restart the kernel** of the notebook where you are using the function. Otherwise, the changes will not be effective.
#
# * **IMPORTANT**: Please make sure that your code executes without any errors before submitting the notebook. An easy way to ensure this is to use the validation script as described in the README.

# %% [markdown]
# # Task 1b - Vision-based angle prediction (20 points)
#
# **Authors:** Chuhan Zhang (C.Zhang-8@tudelft.nl), Tomás Coleman, Maximilian Stölzle
#
# **Warning** To help you, we have marked parts of the code where we want you to contribute. These parts are often marked with a start comment, `Task 1b.i.j: ...` and a closing comment, `Task 1b.i.j: END`. You are free to add code outside of the designated areas. However, we cannot guarantee that this won't affect the intended behavior of the code.
#
# In this file, we will implement two Convolutional Neural Network (CNN) models to predict the position of the single pendulum based on input image data. Each CNN model will try a separate way to predict angles: direct or indirect. Direct prediction means that the network outputs a prediction of the link angle $\hat \theta$, and then updates the network parameters by comparing the loss between the predicted $\hat \theta$ and the label $\theta$. However, indirect prediction means that the dataset has changed. Label is no longer a single angle, but an array containing the $\sin \theta$ value and $\cos \theta$ value of the angle. The output of the network is no longer a single $\hat \theta$, but the predicted $[\hat {\sin \theta}, \hat {\cos \theta}]$. The network updates parameters by comparing the loss between $[\sin \theta, \cos \theta]$ and $[\hat {\sin \theta}, \hat {\cos \theta}]$.
#
# The following cells import all the necessary packages and external functions to run the code properly. First, we want to check whether the images are generated properly and create the directory for output plots and models. Different dataset classes are also created from the information gathered in notebook 1a. Finally, different Pytorch data loaders will be created for each network architecture.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from os import PathLike
from pathlib import Path
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import random_split
from tqdm.notebook import tqdm  # progress bar
from typing import List, Tuple
from distutils.util import strtobool

# define boolean to check if the notebook is run for the purposes of autograding
AUTOGRADING = strtobool(os.environ.get("AUTOGRADING", "false"))


# seed the random number generators
# https://pytorch.org/docs/stable/notes/randomness.html
def manual_seed(seed: int):
    """
    Set manual seeds

    Args:
        seed: Random seed to sett.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)


class DirectoryNotFoundException(Exception):
    """
    Exception raised when a specified directory is not found.

    This exception is used to signal that an operation which expects
    a certain directory to exist has failed because the directory
    was not found in the expected location. It extends the standard
    Exception class and can be used to provide more specific error
    handling that is distinct from general exceptions.

    Attributes:
        None - Inherits all attributes and methods from the base Exception class.

    Methods:
        None - Inherits all methods from the base Exception class and does not
        define any additional behavior.
    """

    pass


class ModelTypeNotFoundException(Exception):
    """
    Exception raised when a specified model type is not found.

    This exception is used in contexts where a specific type of
    model is expected to be present or accessible, but it cannot
    be located or identified. The exception is particularly useful
    in scenarios involving machine learning or data processing
    pipelines where the absence of a required model type can lead
    to failure of the process.

    Attributes:
        None - Inherits all attributes and methods from the base Exception class.

    Methods:
        None - Inherits all methods from the base Exception class and does not
        define any additional behavior.
    """

    pass


# check the directory for datasets
DATASET_DIR = Path("datasets") / "pendulum_dataset"
if not DATASET_DIR.exists():
    raise DirectoryNotFoundException(
        f"The pendulum dataset doesn't exist yet. Please run all cells in the `task_1a_extract_dataset` notebook."
    )

# create the directory for well-trained neural network models
STATEDICTS_DIR = Path("statedicts")
STATEDICTS_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Then, we would like to prepare the training and test sets for the CNNs. In this assignment, we use two ways to predict the state: direct and indirect. Therefore, we prepare the datasets with two formats of labels, called $theta$ and $trig$ respectively.

# %%
class CNNDataset(Dataset):
    """
    A PyTorch dataset class for a CNN, designed to load images and corresponding labels.

    This class extends the PyTorch Dataset class, making it suitable for use with
    PyTorch data loaders and other utilities. It is designed to load image data
    and their associated labels from a specified directory, performing optional
    transformations on the images.
    """

    def __init__(self, dataset_path: PathLike, transform=None):
        """
        Initializes the dataset object with the data path, optional transform, and dataset length.

        Args:
            dataset_path: Path to the directory where image and label files are stored.
            transform: A function/transform that takes in an image and returns a transformed version.
        """

        self.dataset_path = Path(dataset_path)
        self.transform = transform

        # determine the total dataset length
        i = 0
        while (self.dataset_path / f"image{i}.npz").exists():
            i += 1
        self.len = i

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """
        Retrieves an image and its corresponding label at the given index `idx`. The image is
        loaded from a .npz file, optionally transformed, and then returned along with its label
        (both in position form and as sine and cosine components).

        Args:
            idx: The index of the image and label to be loaded.
        Returns:
            x: The image as a torch.Tensor, possibly transformed.
            label_theta: The position label as a torch.FloatTensor
            label_trig: A torch.FloatTensor with two elements, representing the sine and cosine
               components of the label.
        """
        x = np.array(np.load(self.dataset_path / f"image{idx}.npz")["arr_0"])
        if self.transform:
            x = self.transform(x)
        theta = np.load(self.dataset_path / f"label{idx}.npz")["arr_0"]
        sin = np.sin(theta)
        cos = np.cos(theta)

        theta = torch.tensor(np.array(theta)).type(torch.FloatTensor)
        trig = torch.tensor(np.array([sin, cos])).type(torch.FloatTensor)
        return x, theta, trig

    def __len__(self) -> int:
        """
        Returns the total number of samples available in the dataset.

        Returns:
            self.len: The total number of images (or samples) in the dataset.
        """
        return self.len

# %% [markdown]
# The size of the original image data is `500x500x3`, and we want to compress it into a smaller size to save the computation time. Therefore, we add _transforms_ for preprocessing data when building our `Dataset` object. We first use the `ToTensor()` method in PyTorch to convert pixel data distributed between `[0, 255]` into floating point tensor data distributed between `[0, 1]`. Then, we use `Grayscale()` to convert the RGB images into grayscale images. _**Optional question**: Why can we convert the input color image into a grayscale image in this task? Can this be done for all tasks?_ Then we use `CenterCrop()` to extract the center `240x240`px area of the original image, and use `Resize()` to downsample the image to `24x24`px. With this preprocessing pipeline, we obtained training data with each input sample being a tensor of dimension `24x24x1`.

# %%
IMAGE_TRANSFORM = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Grayscale(),
        transforms.CenterCrop(240),
        transforms.Resize((24, 24)),
    ]
)

# %% [markdown]
# It is worth noting that, this `DataLoader` returns three variables: the image $x$, the corresponding label $\theta$, and $[\sin \theta, \cos \theta]$ data. The `DataLoader` is consistent for direct and indirect prediction tasks. You must be careful about using underscores in your code to ignore unnecessary return values for the task.
#
# In this task, we divide the entire data set into three parts: training set, validation set, and test set. The split ratio between training, validation, and testing is 50%, 20%, and 30%. By calling the `load_dataloaders` method, the data loaders for training, validation, and testing are provided.

# %%
def load_dataloaders(
    dataset_path: PathLike,
    val_ratio: float = 0.2,
    test_ratio: float = 0.3,
    batch_size: int = 32,
) -> Tuple[DataLoader, DataLoader, DataLoader]:
    """
    Loads and returns data loaders for training, validation, and testing datasets.

    Args:
        dataset_path: Path to the directory where the dataset is stored.
        val_ratio: The ratio of the dataset to be used for validation.
                    It must be between 0 and 1. Defaults to 0.2.
        test_ratio: The ratio of the dataset to be used for testing.
                    It must be between 0 and 1. Defaults to 0.3.
        batch_size: The number of samples per batch to load. Defaults to 32.

    Returns:
        train_dataloader: The DataLoader instances for the training.
        val_dataloader: The DataLoader instances for the validation.
        test_dataloader: The DataLoader instances for the testing.

    Raises:
        AssertionError: If the sum of val_ratio and test_ratio is larger than 1.0
    """
    assert (
        0.0 <= val_ratio <= 1.0
    ), "Validation ratio needs to be in the interval [0, 1]."
    assert 0.0 <= test_ratio <= 1.0, "Test ratio needs to be in the interval [0, 1]."
    assert (
        val_ratio + test_ratio
    ) <= 1.0, "The sum of val and test ratio needs to be in the interval [0, 1]."

    dataset = CNNDataset(dataset_path, transform=IMAGE_TRANSFORM)
    print(f"The dataset contains {len(dataset)} samples")

    train_size = int(len(dataset) * (1.0 - val_ratio - test_ratio))
    val_size = int(len(dataset) * val_ratio)
    test_size = int(len(dataset) * test_ratio)

    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size]
    )

    train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size, shuffle=False)
    test_dataloader = DataLoader(test_dataset, batch_size, shuffle=False)

    return train_dataloader, val_dataloader, test_dataloader


train_loader, val_loader, test_loader = load_dataloaders(DATASET_DIR)
# Out:
# The dataset contains 3600 samples

# %% [markdown]
# We show the data after preprocessing as below. Do you still remember the colorful, high-resolution dataset samples in task 1a? Now, they have become a low-resolution grayscale image. Please feel free to visualize multiple samples by changing the respective `sample_idx` variable.

# %%
def visualize_dataset_sample(dataset_path: str, sample_idx: int = 1200) -> None:
    """
    Displays a visual representation of an example image from the dataset.

    Args:
        dataset_path: Path to the directory where the dataset is stored.
        sample_idx: The index of the sample to be visualized. Defaults to 1200.

    Returns:
        None: This function only displays an image and does not return any value.
    """
    dataset = CNNDataset(dataset_path, transform=IMAGE_TRANSFORM)
    img_example, _, _ = dataset[sample_idx]
    img_example = img_example.permute(1, 2, 0)
    plt.imshow(img_example, cmap="gray")
    plt.show()


visualize_dataset_sample(DATASET_DIR)

# %% [markdown]
# We already have the function to build training, validation, and testing dataloaders. We will package the evaluation function in the following code block.
#
# Here, during the process of training, we adopt Mean Square Error (MSE) as the loss by invoking `nn.MSELoss()` from PyTorch. During the evalutation process (also in `evaluate_model` method), we adopt Mean Absolute Error (MAE) as the error by invoking `nn.L1Loss()`. _**Optional question:** why do we use MSE in the training process instead of MAE?_

# %%
loss_fn = nn.MSELoss(reduction="mean")
error_fn = nn.L1Loss(reduction="mean")


def evaluate_model(
    model: nn.Module, eval_loader: DataLoader, model_type: str = "theta"
) -> Tuple[float, float]:
    """
    Evaluates the performance of a theta model on a test dataset.

    Args:
        model: The neural network model to be evaluated.
        eval_loader: The DataLoader for the evaluation dataset.
        model_type: The type of model to be evaluated ('theta' or 'trig').
                                    Defaults to 'theta'.

    Returns:
        loss: The mean loss of the model on the valuation dataset.
        error: The mean error of the model on the evaluation dataset.

    Raises:
        ModelTypeNotFoundException: If the provided model_type is neither 'theta' nor 'trig'.

    """
    running_loss = 0.0
    running_error = 0.0
    count = 0.0
    with torch.no_grad():
        for i, (x, theta, trig) in enumerate(eval_loader):
            if model_type == "theta":
                theta_hat = model(x).squeeze(1)

                batch_loss = loss_fn(theta, theta_hat)
                batch_error = error_fn(theta, theta_hat)
            elif model_type == "trig":
                trig_hat = model(x)
                sin_hat = trig_hat[:, 0]
                cos_hat = trig_hat[:, 1]
                sin = trig[:, 0]
                cos = trig[:, 1]
                angle_hat = torch.atan2(sin_hat, cos_hat)
                angle = torch.atan2(sin, cos)

                batch_loss = loss_fn(trig, trig_hat)
                batch_error = error_fn(angle, angle_hat)
            else:
                raise ModelTypeNotFoundException(
                    f"The model type should be either theta or trig."
                )

            running_loss += batch_loss.item()
            running_error += batch_error.item()
            count += 1

    loss = running_loss / count
    error = running_error / count

    return loss, error

# %% [markdown]
# ## Task 1b.1 - Learn to predict angles directly (9.5 points)
# We are going to create models that try to predict the link angles $\hat{\theta}$ given an image of the robot, so $\theta \approx \hat{\theta} =M(x)$.

# %% [markdown]
# ### Tasb 1b.1.1 - Create the CNN model (3.5 points)
# It's time to create a CNN model. Here, create a PyTorch model class called `CNNTheta()`.
# * Start with a convolutional layer `torch.nn.Conv2d(...)` with 32 as the output channel number and a kernel size of `3x3`. This convolutional layer should be followed by a ReLU activation function.
# * Then add an average pooling layer `torch.nn.AvgPool2d(...)` with a pooling kernel size of `2x2`.
# * Add another convolutional layer with `10` as the output channel number and `3x3` as the kernel size. This convolutional layer is also followed by a ReLU function.
# * Add another average pooling layer with the kernel size of `2x2`.
# * Flatten the output of the pooling layer using `torch.nn.Flatten()`.
# * Add a fully connected layer with `30` as the output channel number, with a ReLU activation function.
# * Finally, add another fully connected layer without activation function. Remember, the number of output units must match the dimension of the target data, which is 1.

# %%
"""TASK 1b.1.1: CREATE THETA MODEL HERE"""


# YOUR CODE HERE
class CNNTheta(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.relu1 = nn.ReLU()
        self.avg_pool1 = nn.AvgPool2d(2)
        self.conv2 = nn.Conv2d(32, 10, 3)
        self.relu2 = nn.ReLU()
        self.avg_pool2 = nn.AvgPool2d(2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(160, 30)
        self.relu3 = nn.ReLU()
        self.linear2 = nn.Linear(30, 1)

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.avg_pool1(x)
        
        x = self.relu2(self.conv2(x))
        x = self.avg_pool2(x)
        
        x = self.flatten(x)
        x = self.relu3(self.linear1(x))
        
        x = self.linear2(x)
        return x
        
"""TASK 1b.1.1: END"""

model_theta = CNNTheta()
total_params_theta = sum(p.numel() for p in model_theta.parameters())
print("Total number of trainable model parameters: ", total_params_theta)
# Out:
# Total number of trainable model parameters:  8071

# %% [markdown]
# ### Tasb 1b.1.2 - Train the model (4 points)
# Now that the model is defined, we can train it using the training dataset. Train the model for 50 epochs with the training data `train_loader`. Tune the learning rate in the optimizer to give the best performance on the validation and test set over the 50 epochs. For each training loop, it would be useful to test the model performance on the validation set to see if it is overfitting the training data or can generalize well. Do this 3 times and use the validation dataset `val_loader` with the function `evaluate_model` to get the validation result.
#
# **Hints:**
# - When we iterate over the training set, we use `(x, theta, _)` or something similar where `_` is used to ignore `trig`.
# - Reduce the number of epochs and lower the number of runs to `1` while getting your model working and setting the optimal learning rate.
# - Try varying the learning rate in the `1e-1` to `1e-5` range.

# %%
# set the number of runs (i.e., different random seeds)
num_runs = 3  # Change to 1 until you get it to work once
# number of epochs we train each model for
num_epochs = 50

# %%
if not AUTOGRADING:
    """TASK 1b.1.2: TRAIN MODEL HERE"""
    for run in range(num_runs):
        print(f"Starting run {run}")
        # set new random seed
        manual_seed(seed=run)
        # this code reinitializes the parameters of the model on each loop
        model_theta = CNNTheta()

        # define the optimizer
        optimizer = torch.optim.SGD(model_theta.parameters(), lr=8e-4)

        # YOUR CODE HERE
        for epoch in range(num_epochs):
            model_theta.train()
            running_loss = 0.0
            for x, theta, _ in train_loader:
                optimizer.zero_grad()
                theta_hat = model_theta(x)
                loss = loss_fn(theta_hat.squeeze(1), theta)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

            val_loss, val_error = evaluate_model(model_theta, val_loader, model_type="theta")
            avg_train_loss = running_loss / len(train_loader)
            print(
                f"Epoch {epoch+1}/{num_epochs} | train_loss={avg_train_loss:.4f} | "
                f"val_loss={val_loss:.4f} | val_error={val_error:.4f} rad"
            )
        
        run_test_loss, run_test_error = evaluate_model(
            model_theta, test_loader, model_type="theta"
        )
        print(
            f"Run {run} finished with a test loss of {run_test_loss:.4} rad^2 and a mean test error of {run_test_error:.4} rad."
        )

        # save the model
        torch.save(
            model_theta.state_dict(),
            STATEDICTS_DIR / f"task_1b_theta_model_run-{run}.pth",
            _use_new_zipfile_serialization=False,
        )
    """TASK 1.1.2: END"""
# Out:
# Starting run 0
# Epoch 1/50 | train_loss=9.2702 | val_loss=3.1480 | val_error=1.5140 rad
# Epoch 2/50 | train_loss=3.2922 | val_loss=3.1406 | val_error=1.5151 rad
# Epoch 3/50 | train_loss=3.2487 | val_loss=3.1465 | val_error=1.5160 rad
# Epoch 4/50 | train_loss=3.2800 | val_loss=3.0933 | val_error=1.5016 rad
# Epoch 5/50 | train_loss=3.2609 | val_loss=3.0932 | val_error=1.5017 rad
# Epoch 6/50 | train_loss=3.2247 | val_loss=3.0744 | val_error=1.4962 rad
# Epoch 7/50 | train_loss=3.1926 | val_loss=3.0359 | val_error=1.4857 rad
# Epoch 8/50 | train_loss=3.1927 | val_loss=3.0570 | val_error=1.4787 rad
# Epoch 9/50 | train_loss=3.1470 | val_loss=3.0009 | val_error=1.4752 rad
# Epoch 10/50 | train_loss=3.1032 | val_loss=2.9797 | val_error=1.4689 rad
# Epoch 11/50 | train_loss=3.0917 | val_loss=2.9182 | val_error=1.4515 rad
# Epoch 12/50 | train_loss=3.0430 | val_loss=2.8971 | val_error=1.4449 rad
# Epoch 13/50 | train_loss=2.9975 | val_loss=2.8959 | val_error=1.4428 rad
# Epoch 14/50 | train_loss=2.9518 | val_loss=2.7727 | val_error=1.4033 rad
# Epoch 15/50 | train_loss=2.8977 | val_loss=2.7556 | val_error=1.4010 rad
# Epoch 16/50 | train_loss=2.7822 | val_loss=2.6312 | val_error=1.3643 rad
# Epoch 17/50 | train_loss=2.6898 | val_loss=2.4700 | val_error=1.3117 rad
# Epoch 18/50 | train_loss=2.5332 | val_loss=2.3831 | val_error=1.2840 rad
# Epoch 19/50 | train_loss=2.3589 | val_loss=2.1981 | val_error=1.2215 rad
# Epoch 20/50 | train_loss=2.1564 | val_loss=1.8872 | val_error=1.0952 rad
# Epoch 21/50 | train_loss=1.8702 | val_loss=1.6008 | val_error=0.9703 rad
# Epoch 22/50 | train_loss=1.5316 | val_loss=1.2393 | val_error=0.7978 rad
# Epoch 23/50 | train_loss=1.2843 | val_loss=1.1593 | val_error=0.8026 rad
# Epoch 24/50 | train_loss=1.3728 | val_loss=0.8196 | val_error=0.5848 rad
# Epoch 25/50 | train_loss=1.3358 | val_loss=0.8951 | val_error=0.7067 rad
# Epoch 26/50 | train_loss=1.2939 | val_loss=1.0505 | val_error=0.8275 rad
# Epoch 27/50 | train_loss=0.9287 | val_loss=0.5967 | val_error=0.4061 rad
# Epoch 28/50 | train_loss=0.8628 | val_loss=1.2635 | val_error=0.9553 rad
# Epoch 29/50 | train_loss=1.1062 | val_loss=0.5238 | val_error=0.3752 rad
# Epoch 30/50 | train_loss=0.9411 | val_loss=1.0956 | val_error=0.8948 rad
# Epoch 31/50 | train_loss=0.8760 | val_loss=0.6848 | val_error=0.6267 rad
# Epoch 32/50 | train_loss=0.8870 | val_loss=0.4752 | val_error=0.3541 rad
# Epoch 33/50 | train_loss=0.7270 | val_loss=0.4476 | val_error=0.3418 rad
# Epoch 34/50 | train_loss=0.7538 | val_loss=0.8811 | val_error=0.7723 rad
# Epoch 35/50 | train_loss=0.7700 | val_loss=0.6042 | val_error=0.5659 rad
# Epoch 36/50 | train_loss=0.6833 | val_loss=0.5354 | val_error=0.5040 rad
# Epoch 37/50 | train_loss=0.7199 | val_loss=0.4113 | val_error=0.3035 rad
# Epoch 38/50 | train_loss=0.7048 | val_loss=1.0890 | val_error=0.9206 rad
# Epoch 39/50 | train_loss=0.6631 | val_loss=0.5701 | val_error=0.5515 rad
# Epoch 40/50 | train_loss=0.5997 | val_loss=0.4037 | val_error=0.3421 rad
# Epoch 41/50 | train_loss=0.6034 | val_loss=0.3926 | val_error=0.3298 rad
# Epoch 42/50 | train_loss=0.4863 | val_loss=0.4409 | val_error=0.4372 rad
# Epoch 43/50 | train_loss=0.7390 | val_loss=0.9402 | val_error=0.8090 rad
# Epoch 44/50 | train_loss=0.5936 | val_loss=0.3880 | val_error=0.3746 rad
# Epoch 45/50 | train_loss=0.4648 | val_loss=0.3693 | val_error=0.3443 rad
# Epoch 46/50 | train_loss=0.4698 | val_loss=0.5811 | val_error=0.5863 rad
# Epoch 47/50 | train_loss=0.4705 | val_loss=0.4713 | val_error=0.4909 rad
# Epoch 48/50 | train_loss=0.4984 | val_loss=0.4441 | val_error=0.4630 rad
# Epoch 49/50 | train_loss=0.5545 | val_loss=0.3320 | val_error=0.3026 rad
# Epoch 50/50 | train_loss=0.5095 | val_loss=1.6893 | val_error=1.1444 rad
# Run 0 finished with a test loss of 1.64 rad^2 and a mean test error of 1.145 rad.
# Starting run 1
# Epoch 1/50 | train_loss=12.8464 | val_loss=10.6799 | val_error=2.7536 rad
# Epoch 2/50 | train_loss=5.9285 | val_loss=3.1566 | val_error=1.5088 rad
# Epoch 3/50 | train_loss=3.2735 | val_loss=3.0969 | val_error=1.5020 rad
# Epoch 4/50 | train_loss=3.2467 | val_loss=3.0987 | val_error=1.5034 rad
# Epoch 5/50 | train_loss=3.2004 | val_loss=3.0508 | val_error=1.4856 rad
# Epoch 6/50 | train_loss=3.1893 | val_loss=3.0250 | val_error=1.4824 rad
# Epoch 7/50 | train_loss=3.1834 | val_loss=3.0207 | val_error=1.4704 rad
# Epoch 8/50 | train_loss=3.1507 | val_loss=2.9888 | val_error=1.4604 rad
# Epoch 9/50 | train_loss=3.0996 | val_loss=2.9390 | val_error=1.4572 rad
# Epoch 10/50 | train_loss=3.0603 | val_loss=2.8681 | val_error=1.4362 rad
# Epoch 11/50 | train_loss=3.0005 | val_loss=2.7969 | val_error=1.4105 rad
# Epoch 12/50 | train_loss=2.9250 | val_loss=2.7360 | val_error=1.3871 rad
# Epoch 13/50 | train_loss=2.8353 | val_loss=2.6151 | val_error=1.3558 rad
# Epoch 14/50 | train_loss=2.7371 | val_loss=2.7021 | val_error=1.3805 rad
# Epoch 15/50 | train_loss=2.5675 | val_loss=2.4975 | val_error=1.2867 rad
# Epoch 16/50 | train_loss=2.4168 | val_loss=2.3051 | val_error=1.2593 rad
# Epoch 17/50 | train_loss=2.1325 | val_loss=2.4731 | val_error=1.2489 rad
# Epoch 18/50 | train_loss=1.8741 | val_loss=1.4779 | val_error=0.9251 rad
# Epoch 19/50 | train_loss=1.6522 | val_loss=3.2273 | val_error=1.5276 rad
# Epoch 20/50 | train_loss=1.5006 | val_loss=1.6154 | val_error=1.0494 rad
# Epoch 21/50 | train_loss=1.6314 | val_loss=1.4734 | val_error=0.9534 rad
# Epoch 22/50 | train_loss=1.2656 | val_loss=0.9201 | val_error=0.6862 rad
# Epoch 23/50 | train_loss=1.6322 | val_loss=1.8925 | val_error=1.1482 rad
# Epoch 24/50 | train_loss=1.1856 | val_loss=0.6846 | val_error=0.4693 rad
# Epoch 25/50 | train_loss=1.1780 | val_loss=0.7422 | val_error=0.5755 rad
# Epoch 26/50 | train_loss=1.2117 | val_loss=3.3315 | val_error=1.7112 rad
# Epoch 27/50 | train_loss=1.1712 | val_loss=0.5812 | val_error=0.3649 rad
# Epoch 28/50 | train_loss=0.9618 | val_loss=0.8752 | val_error=0.7436 rad
# Epoch 29/50 | train_loss=0.9601 | val_loss=0.6879 | val_error=0.5965 rad
# Epoch 30/50 | train_loss=0.8073 | val_loss=1.6230 | val_error=1.1568 rad
# Epoch 31/50 | train_loss=0.9361 | val_loss=0.5749 | val_error=0.4894 rad
# Epoch 32/50 | train_loss=0.8281 | val_loss=0.9497 | val_error=0.8237 rad
# Epoch 33/50 | train_loss=0.7461 | val_loss=2.0335 | val_error=1.2849 rad
# Epoch 34/50 | train_loss=0.7380 | val_loss=0.5054 | val_error=0.4299 rad
# Epoch 35/50 | train_loss=0.5980 | val_loss=0.4419 | val_error=0.3199 rad
# Epoch 36/50 | train_loss=0.6530 | val_loss=0.7200 | val_error=0.6775 rad
# Epoch 37/50 | train_loss=0.6548 | val_loss=0.4207 | val_error=0.3078 rad
# Epoch 38/50 | train_loss=0.6126 | val_loss=0.5517 | val_error=0.5397 rad
# Epoch 39/50 | train_loss=0.6352 | val_loss=0.4428 | val_error=0.3981 rad
# Epoch 40/50 | train_loss=0.5074 | val_loss=0.4970 | val_error=0.4864 rad
# Epoch 41/50 | train_loss=0.5179 | val_loss=0.4261 | val_error=0.4012 rad
# Epoch 42/50 | train_loss=0.5965 | val_loss=0.7377 | val_error=0.7045 rad
# Epoch 43/50 | train_loss=0.6347 | val_loss=0.4163 | val_error=0.3776 rad
# Epoch 44/50 | train_loss=0.5512 | val_loss=0.3744 | val_error=0.3114 rad
# Epoch 45/50 | train_loss=0.5792 | val_loss=0.6368 | val_error=0.6319 rad
# Epoch 46/50 | train_loss=0.5043 | val_loss=0.3402 | val_error=0.2593 rad
# Epoch 47/50 | train_loss=0.5270 | val_loss=0.3781 | val_error=0.3769 rad
# Epoch 48/50 | train_loss=0.5532 | val_loss=0.9190 | val_error=0.8234 rad
# Epoch 49/50 | train_loss=0.5026 | val_loss=0.3469 | val_error=0.3158 rad
# Epoch 50/50 | train_loss=0.4635 | val_loss=0.3301 | val_error=0.2951 rad
# Run 1 finished with a test loss of 0.3708 rad^2 and a mean test error of 0.3088 rad.
# Starting run 2
# Epoch 1/50 | train_loss=11.4681 | val_loss=4.3027 | val_error=1.7057 rad
# Epoch 2/50 | train_loss=3.3747 | val_loss=3.0997 | val_error=1.5045 rad
# Epoch 3/50 | train_loss=3.2723 | val_loss=3.0781 | val_error=1.4997 rad
# Epoch 4/50 | train_loss=3.2226 | val_loss=3.0578 | val_error=1.4911 rad
# Epoch 5/50 | train_loss=3.2052 | val_loss=3.0373 | val_error=1.4891 rad
# Epoch 6/50 | train_loss=3.1713 | val_loss=3.0402 | val_error=1.4900 rad
# Epoch 7/50 | train_loss=3.1731 | val_loss=2.9899 | val_error=1.4757 rad
# Epoch 8/50 | train_loss=3.1342 | val_loss=2.9432 | val_error=1.4606 rad
# Epoch 9/50 | train_loss=3.0997 | val_loss=2.9313 | val_error=1.4588 rad
# Epoch 10/50 | train_loss=3.0453 | val_loss=2.8667 | val_error=1.4389 rad
# Epoch 11/50 | train_loss=3.0048 | val_loss=2.8138 | val_error=1.4217 rad
# Epoch 12/50 | train_loss=2.9278 | val_loss=2.7666 | val_error=1.4097 rad
# Epoch 13/50 | train_loss=2.8732 | val_loss=2.7195 | val_error=1.3961 rad
# Epoch 14/50 | train_loss=2.7773 | val_loss=2.5941 | val_error=1.3509 rad
# Epoch 15/50 | train_loss=2.6945 | val_loss=2.4755 | val_error=1.3167 rad
# Epoch 16/50 | train_loss=2.5469 | val_loss=2.3256 | val_error=1.2676 rad
# Epoch 17/50 | train_loss=2.3791 | val_loss=2.2996 | val_error=1.2266 rad
# Epoch 18/50 | train_loss=2.1961 | val_loss=1.9181 | val_error=1.0999 rad
# Epoch 19/50 | train_loss=1.8993 | val_loss=1.6989 | val_error=1.0508 rad
# Epoch 20/50 | train_loss=1.5500 | val_loss=1.2963 | val_error=0.8741 rad
# Epoch 21/50 | train_loss=1.2765 | val_loss=1.1695 | val_error=0.7954 rad
# Epoch 22/50 | train_loss=1.0378 | val_loss=0.9553 | val_error=0.7135 rad
# Epoch 23/50 | train_loss=1.1480 | val_loss=1.2564 | val_error=0.9072 rad
# Epoch 24/50 | train_loss=1.0488 | val_loss=3.5612 | val_error=1.6093 rad
# Epoch 25/50 | train_loss=1.0212 | val_loss=1.9931 | val_error=1.1947 rad
# Epoch 26/50 | train_loss=0.9210 | val_loss=0.7905 | val_error=0.6754 rad
# Epoch 27/50 | train_loss=0.8123 | val_loss=0.8485 | val_error=0.7498 rad
# Epoch 28/50 | train_loss=0.7927 | val_loss=0.6228 | val_error=0.5527 rad
# Epoch 29/50 | train_loss=0.6885 | val_loss=0.5379 | val_error=0.4749 rad
# Epoch 30/50 | train_loss=0.6974 | val_loss=0.6281 | val_error=0.5800 rad
# Epoch 31/50 | train_loss=0.6508 | val_loss=0.8851 | val_error=0.7542 rad
# Epoch 32/50 | train_loss=0.7156 | val_loss=0.6289 | val_error=0.5825 rad
# Epoch 33/50 | train_loss=0.7241 | val_loss=0.4555 | val_error=0.4095 rad
# Epoch 34/50 | train_loss=0.7720 | val_loss=0.8774 | val_error=0.7641 rad
# Epoch 35/50 | train_loss=0.5733 | val_loss=0.3801 | val_error=0.2808 rad
# Epoch 36/50 | train_loss=0.5632 | val_loss=0.7317 | val_error=0.6787 rad
# Epoch 37/50 | train_loss=0.6315 | val_loss=0.8698 | val_error=0.7659 rad
# Epoch 38/50 | train_loss=0.5210 | val_loss=0.4319 | val_error=0.4150 rad
# Epoch 39/50 | train_loss=0.5646 | val_loss=0.3466 | val_error=0.2630 rad
# Epoch 40/50 | train_loss=0.4919 | val_loss=0.6886 | val_error=0.6786 rad
# Epoch 41/50 | train_loss=0.5803 | val_loss=0.3531 | val_error=0.3243 rad
# Epoch 42/50 | train_loss=0.5948 | val_loss=1.2666 | val_error=1.0009 rad
# Epoch 43/50 | train_loss=0.5136 | val_loss=0.3217 | val_error=0.2498 rad
# Epoch 44/50 | train_loss=0.4451 | val_loss=0.3614 | val_error=0.3616 rad
# Epoch 45/50 | train_loss=0.4944 | val_loss=0.5990 | val_error=0.6173 rad
# Epoch 46/50 | train_loss=0.4416 | val_loss=0.3153 | val_error=0.2724 rad
# Epoch 47/50 | train_loss=0.4311 | val_loss=0.5644 | val_error=0.5793 rad
# Epoch 48/50 | train_loss=0.5216 | val_loss=0.2941 | val_error=0.2231 rad
# Epoch 49/50 | train_loss=0.4189 | val_loss=0.6006 | val_error=0.6010 rad
# Epoch 50/50 | train_loss=0.4748 | val_loss=0.3352 | val_error=0.3508 rad
# Run 2 finished with a test loss of 0.3946 rad^2 and a mean test error of 0.3631 rad.

# %% [markdown]
# Evaluate the final result on the `test_loader` using the function `evaluate_model`. The `model_type` is `theta` in this situation.

# %%
# evaluate the theta model on the test set
test_error_across_runs_theta = np.zeros((num_runs,))
for run in range(num_runs):
    model_theta.load_state_dict(
        torch.load(STATEDICTS_DIR / f"task_1b_theta_model_run-{run}.pth")
    )
    run_test_loss, run_test_error = evaluate_model(
        model_theta, test_loader, model_type="theta"
    )
    test_error_across_runs_theta[run] = run_test_error
print(
    f"Prediction error of theta model across runs: {np.mean(test_error_across_runs_theta):.4} += {np.std(test_error_across_runs_theta):.4} rad."
)
# Out:
# Prediction error of theta model across runs: 0.5037 += 0.3807 rad.

# %% [markdown]
# ### Tasb 1b.1.3 - Analyse model performance (2 points)
# Evaluate the trained model's accuracy by examining the average error in the link angle prediction. Please analyze the training loss curve: does the training loss decrease step by step? (1 point)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# We always use a separate test dataset to evaluate a trained model. What is the reason for this? (1 point)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Task 1b.2 - Indirectly predict the angle (10.5 points)
# We are going to improve the accuracy by pre-processing the target data. Specifically, we will create a model $M_{trig}$ that learns to predict $\sin(\theta)$ and $\cos(\theta)$ for the pendulum instead of directly predicting $\theta$. Then, we can use the inverse tangent function to retrieve an estimate of $\theta$ for both links.
#
# *Note:* In practice you would use the `atan2` implementation, as the regular arctangent only covers $[-\frac{1}{2}\pi, \frac{1}{2}\pi]$} $\theta=\arctan(\frac{\sin(\theta)}{\cos(\theta)})$

# %% [markdown]
# ### Task 1b.2.1 - Create the model (3.5 points)
# Copy the model you created in Task 1.1. Change the number of hidden units of the final layer from 1 to 2. We do so because we now want to predict two outputs ($\sin(\theta)$, $\cos(\theta)$) for each sample. The total number of the model parameters should increase slightly compared to Task 1.1. _**Optional question:** Why does the number of model parameters increase?_

# %%
"""TASK 1b.2.1: CREATE TRIGONOMETRIC MODEL HERE"""


# YOUR CODE HERE
class CNNTrig(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.relu1 = nn.ReLU()
        self.avg_pool1 = nn.AvgPool2d(2)
        self.conv2 = nn.Conv2d(32, 10, 3)
        self.relu2 = nn.ReLU()
        self.avg_pool2 = nn.AvgPool2d(2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(160, 30)
        self.relu3 = nn.ReLU()
        self.linear2 = nn.Linear(30, 2)

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.avg_pool1(x)
        
        x = self.relu2(self.conv2(x))
        x = self.avg_pool2(x)
        
        x = self.flatten(x)
        x = self.relu3(self.linear1(x))
        
        x = self.linear2(x)
        return x
"""TASK 1b.2.1: END"""

model_trig = CNNTrig()
total_params_trig = sum(p.numel() for p in model_trig.parameters())
print("total number of model parameters: ", total_params_trig)
# Out:
# total number of model parameters:  8102

# %% [markdown]
# ### Task 1b.2.2 - Train the model (4 points)
# Now train a model with the same training hyperparameters as in task 1.1 but using the the trigonometric labels. When dealing with the return value of the `train_loader,` be careful to make sure that the output is the $[\sin(\theta)$, $\cos(\theta)]$ instead of $\theta$. Tune the learning rate in the optimizer to give the best performance on the validation and test set over the 50 epochs. Do this 3 times like the previous task.
#
# **Hint:**
# - We utilize the third instead of the second item in the tuple returned by the dataloader. Therefore, when we iterate over the training set, we use `(x, _, trig)` where `_` is applied to ignore `theta`. Here, `trig` is a tensor containing $\sin$ value and $\cos$ value
# - Reduce the number of epochs and lower the number of runs to `1` while getting your model working.
# - Try in the range `1e-1` to `1e-5` for the learning rate

# %%
# set the number of runs (i.e., different random seeds)
num_runs = 3  # Change to 1 until you get it to work once
# number of epochs we train each model for
num_epochs = 50

# %%
if not AUTOGRADING:
    """TASK 1b.2.2: TRAIN TRIGONOMETRIC MODEL HERE"""
    for run in range(num_runs):
        print(f"Starting run {run}")
        # set new random seed
        manual_seed(seed=run)
        # this code reinitializes the parameters of the model on each loop
        model_trig = CNNTrig()

        # define the optimizer
        optimizer = torch.optim.SGD(model_trig.parameters(), lr=1e-2)

        # YOUR CODE HERE
        for epoch in range(num_epochs):
            model_trig.train()
            running_loss = 0.0
            for x, _, trig in train_loader:
                optimizer.zero_grad()
                trig_hat = model_trig(x)
                # angle_hat = torch.atan2(trig_hat[:, 0], trig_hat[:, 1])
                # angle = torch.atan2(trig[:, 0], trig[:, 1])
                
                loss = loss_fn(trig_hat, trig)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

            val_loss, val_error = evaluate_model(model_trig, val_loader, model_type="trig")
            avg_train_loss = running_loss / len(train_loader)
            print(
                f"Epoch {epoch+1}/{num_epochs} | train_loss={avg_train_loss:.4f} | "
                f"val_loss={val_loss:.4f} | val_error={val_error:.4f} rad"
            )
                    
        run_test_loss, run_test_error = evaluate_model(
            model_trig, test_loader, model_type="trig"
        )
        print(
            f"Run {run} finished with a test loss of {run_test_loss:.4} and a mean test error of {run_test_error:.4} rad."
        )

        # save the model
        torch.save(
            model_trig.state_dict(),
            STATEDICTS_DIR / f"task_1b_trig_model_run-{run}.pth",
            _use_new_zipfile_serialization=False,
        )
    """TASK 1b.2.2: END"""
# Out:
# Starting run 0
# Epoch 1/50 | train_loss=0.5010 | val_loss=0.4954 | val_error=2.4853 rad
# Epoch 2/50 | train_loss=0.4942 | val_loss=0.4925 | val_error=2.1998 rad
# Epoch 3/50 | train_loss=0.4912 | val_loss=0.4890 | val_error=0.4696 rad
# Epoch 4/50 | train_loss=0.4878 | val_loss=0.4849 | val_error=1.2251 rad
# Epoch 5/50 | train_loss=0.4828 | val_loss=0.4779 | val_error=1.6737 rad
# Epoch 6/50 | train_loss=0.4747 | val_loss=0.4684 | val_error=2.5421 rad
# Epoch 7/50 | train_loss=0.4630 | val_loss=0.4565 | val_error=1.3244 rad
# Epoch 8/50 | train_loss=0.4397 | val_loss=0.4194 | val_error=0.4272 rad
# Epoch 9/50 | train_loss=0.3961 | val_loss=0.3788 | val_error=1.9849 rad
# Epoch 10/50 | train_loss=0.3167 | val_loss=0.2570 | val_error=1.1180 rad
# Epoch 11/50 | train_loss=0.2971 | val_loss=0.2288 | val_error=1.0378 rad
# Epoch 12/50 | train_loss=0.2264 | val_loss=0.1693 | val_error=0.5894 rad
# Epoch 13/50 | train_loss=0.1671 | val_loss=0.2210 | val_error=1.1683 rad
# Epoch 14/50 | train_loss=0.1158 | val_loss=0.0357 | val_error=0.2426 rad
# Epoch 15/50 | train_loss=0.0579 | val_loss=0.0276 | val_error=0.4163 rad
# Epoch 16/50 | train_loss=0.0293 | val_loss=0.0124 | val_error=0.1965 rad
# Epoch 17/50 | train_loss=0.0187 | val_loss=0.0055 | val_error=0.1519 rad
# Epoch 18/50 | train_loss=0.0117 | val_loss=0.0070 | val_error=0.1705 rad
# Epoch 19/50 | train_loss=0.0056 | val_loss=0.0044 | val_error=0.1502 rad
# Epoch 20/50 | train_loss=0.0020 | val_loss=0.0009 | val_error=0.0542 rad
# Epoch 21/50 | train_loss=0.0022 | val_loss=0.0029 | val_error=0.1000 rad
# Epoch 22/50 | train_loss=0.0015 | val_loss=0.0069 | val_error=0.1760 rad
# Epoch 23/50 | train_loss=0.0026 | val_loss=0.0007 | val_error=0.0376 rad
# Epoch 24/50 | train_loss=0.0013 | val_loss=0.0011 | val_error=0.0573 rad
# Epoch 25/50 | train_loss=0.0012 | val_loss=0.0009 | val_error=0.0385 rad
# Epoch 26/50 | train_loss=0.0022 | val_loss=0.0042 | val_error=0.1529 rad
# Epoch 27/50 | train_loss=0.0011 | val_loss=0.0014 | val_error=0.0689 rad
# Epoch 28/50 | train_loss=0.0008 | val_loss=0.0015 | val_error=0.0792 rad
# Epoch 29/50 | train_loss=0.0013 | val_loss=0.0004 | val_error=0.0557 rad
# Epoch 30/50 | train_loss=0.0014 | val_loss=0.0025 | val_error=0.0900 rad
# Epoch 31/50 | train_loss=0.0008 | val_loss=0.0005 | val_error=0.0514 rad
# Epoch 32/50 | train_loss=0.0005 | val_loss=0.0006 | val_error=0.0189 rad
# Epoch 33/50 | train_loss=0.0008 | val_loss=0.0003 | val_error=0.0211 rad
# Epoch 34/50 | train_loss=0.0006 | val_loss=0.0003 | val_error=0.0295 rad
# Epoch 35/50 | train_loss=0.0005 | val_loss=0.0008 | val_error=0.0831 rad
# Epoch 36/50 | train_loss=0.0003 | val_loss=0.0004 | val_error=0.0167 rad
# Epoch 37/50 | train_loss=0.0004 | val_loss=0.0003 | val_error=0.0460 rad
# Epoch 38/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0285 rad
# Epoch 39/50 | train_loss=0.0008 | val_loss=0.0002 | val_error=0.0271 rad
# Epoch 40/50 | train_loss=0.0003 | val_loss=0.0003 | val_error=0.0318 rad
# Epoch 41/50 | train_loss=0.0004 | val_loss=0.0002 | val_error=0.0262 rad
# Epoch 42/50 | train_loss=0.0005 | val_loss=0.0002 | val_error=0.0259 rad
# Epoch 43/50 | train_loss=0.0003 | val_loss=0.0008 | val_error=0.0856 rad
# Epoch 44/50 | train_loss=0.0006 | val_loss=0.0002 | val_error=0.0271 rad
# Epoch 45/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0282 rad
# Epoch 46/50 | train_loss=0.0002 | val_loss=0.0003 | val_error=0.0566 rad
# Epoch 47/50 | train_loss=0.0003 | val_loss=0.0003 | val_error=0.0320 rad
# Epoch 48/50 | train_loss=0.0002 | val_loss=0.0005 | val_error=0.0185 rad
# Epoch 49/50 | train_loss=0.0003 | val_loss=0.0003 | val_error=0.0131 rad
# Epoch 50/50 | train_loss=0.0003 | val_loss=0.0006 | val_error=0.0555 rad
# Run 0 finished with a test loss of 0.0006015 and a mean test error of 0.04492 rad.
# Starting run 1
# Epoch 1/50 | train_loss=0.5038 | val_loss=0.4984 | val_error=2.7764 rad
# Epoch 2/50 | train_loss=0.4982 | val_loss=0.4970 | val_error=2.6628 rad
# Epoch 3/50 | train_loss=0.4966 | val_loss=0.4954 | val_error=1.8922 rad
# Epoch 4/50 | train_loss=0.4948 | val_loss=0.4939 | val_error=0.8246 rad
# Epoch 5/50 | train_loss=0.4931 | val_loss=0.4920 | val_error=1.1924 rad
# Epoch 6/50 | train_loss=0.4908 | val_loss=0.4898 | val_error=1.2733 rad
# Epoch 7/50 | train_loss=0.4874 | val_loss=0.4857 | val_error=0.8441 rad
# Epoch 8/50 | train_loss=0.4822 | val_loss=0.4789 | val_error=0.7614 rad
# Epoch 9/50 | train_loss=0.4737 | val_loss=0.4713 | val_error=1.2798 rad
# Epoch 10/50 | train_loss=0.4596 | val_loss=0.4494 | val_error=0.9780 rad
# Epoch 11/50 | train_loss=0.4342 | val_loss=0.4163 | val_error=1.6899 rad
# Epoch 12/50 | train_loss=0.3811 | val_loss=0.4246 | val_error=1.3638 rad
# Epoch 13/50 | train_loss=0.3035 | val_loss=0.5557 | val_error=1.8001 rad
# Epoch 14/50 | train_loss=0.3008 | val_loss=0.1758 | val_error=0.4005 rad
# Epoch 15/50 | train_loss=0.2295 | val_loss=0.1678 | val_error=0.9217 rad
# Epoch 16/50 | train_loss=0.1620 | val_loss=0.0862 | val_error=0.3886 rad
# Epoch 17/50 | train_loss=0.1261 | val_loss=0.1109 | val_error=0.5800 rad
# Epoch 18/50 | train_loss=0.0930 | val_loss=0.1157 | val_error=0.8462 rad
# Epoch 19/50 | train_loss=0.0608 | val_loss=0.0222 | val_error=0.2931 rad
# Epoch 20/50 | train_loss=0.0307 | val_loss=0.0119 | val_error=0.2131 rad
# Epoch 21/50 | train_loss=0.0170 | val_loss=0.0125 | val_error=0.1914 rad
# Epoch 22/50 | train_loss=0.0114 | val_loss=0.0022 | val_error=0.0379 rad
# Epoch 23/50 | train_loss=0.0107 | val_loss=0.0025 | val_error=0.1007 rad
# Epoch 24/50 | train_loss=0.0054 | val_loss=0.0170 | val_error=0.2154 rad
# Epoch 25/50 | train_loss=0.0047 | val_loss=0.0017 | val_error=0.0703 rad
# Epoch 26/50 | train_loss=0.0025 | val_loss=0.0014 | val_error=0.0664 rad
# Epoch 27/50 | train_loss=0.0031 | val_loss=0.0016 | val_error=0.0749 rad
# Epoch 28/50 | train_loss=0.0035 | val_loss=0.0063 | val_error=0.0730 rad
# Epoch 29/50 | train_loss=0.0017 | val_loss=0.0012 | val_error=0.0646 rad
# Epoch 30/50 | train_loss=0.0018 | val_loss=0.0011 | val_error=0.0662 rad
# Epoch 31/50 | train_loss=0.0014 | val_loss=0.0008 | val_error=0.0197 rad
# Epoch 32/50 | train_loss=0.0018 | val_loss=0.0013 | val_error=0.0817 rad
# Epoch 33/50 | train_loss=0.0010 | val_loss=0.0020 | val_error=0.1109 rad
# Epoch 34/50 | train_loss=0.0013 | val_loss=0.0010 | val_error=0.0612 rad
# Epoch 35/50 | train_loss=0.0009 | val_loss=0.0008 | val_error=0.0377 rad
# Epoch 36/50 | train_loss=0.0009 | val_loss=0.0006 | val_error=0.0490 rad
# Epoch 37/50 | train_loss=0.0007 | val_loss=0.0008 | val_error=0.0614 rad
# Epoch 38/50 | train_loss=0.0007 | val_loss=0.0005 | val_error=0.0162 rad
# Epoch 39/50 | train_loss=0.0006 | val_loss=0.0005 | val_error=0.0140 rad
# Epoch 40/50 | train_loss=0.0006 | val_loss=0.0005 | val_error=0.0308 rad
# Epoch 41/50 | train_loss=0.0006 | val_loss=0.0011 | val_error=0.0691 rad
# Epoch 42/50 | train_loss=0.0010 | val_loss=0.0007 | val_error=0.0537 rad
# Epoch 43/50 | train_loss=0.0006 | val_loss=0.0016 | val_error=0.0801 rad
# Epoch 44/50 | train_loss=0.0006 | val_loss=0.0006 | val_error=0.0438 rad
# Epoch 45/50 | train_loss=0.0010 | val_loss=0.0009 | val_error=0.0645 rad
# Epoch 46/50 | train_loss=0.0005 | val_loss=0.0004 | val_error=0.0122 rad
# Epoch 47/50 | train_loss=0.0006 | val_loss=0.0003 | val_error=0.0278 rad
# Epoch 48/50 | train_loss=0.0008 | val_loss=0.0010 | val_error=0.0716 rad
# Epoch 49/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0280 rad
# Epoch 50/50 | train_loss=0.0005 | val_loss=0.0004 | val_error=0.0296 rad
# Run 1 finished with a test loss of 0.0003618 and a mean test error of 0.02385 rad.
# Starting run 2
# Epoch 1/50 | train_loss=0.5015 | val_loss=0.5009 | val_error=1.7531 rad
# Epoch 2/50 | train_loss=0.4983 | val_loss=0.4981 | val_error=1.6283 rad
# Epoch 3/50 | train_loss=0.4968 | val_loss=0.4962 | val_error=1.4166 rad
# Epoch 4/50 | train_loss=0.4954 | val_loss=0.4944 | val_error=1.0871 rad
# Epoch 5/50 | train_loss=0.4935 | val_loss=0.4924 | val_error=1.2529 rad
# Epoch 6/50 | train_loss=0.4913 | val_loss=0.4899 | val_error=1.1687 rad
# Epoch 7/50 | train_loss=0.4883 | val_loss=0.4857 | val_error=1.0925 rad
# Epoch 8/50 | train_loss=0.4839 | val_loss=0.4811 | val_error=0.7447 rad
# Epoch 9/50 | train_loss=0.4774 | val_loss=0.4741 | val_error=1.0000 rad
# Epoch 10/50 | train_loss=0.4667 | val_loss=0.4589 | val_error=0.3807 rad
# Epoch 11/50 | train_loss=0.4486 | val_loss=0.4362 | val_error=1.6889 rad
# Epoch 12/50 | train_loss=0.4160 | val_loss=0.4101 | val_error=2.2219 rad
# Epoch 13/50 | train_loss=0.3537 | val_loss=0.3131 | val_error=1.0707 rad
# Epoch 14/50 | train_loss=0.2484 | val_loss=0.3216 | val_error=1.1379 rad
# Epoch 15/50 | train_loss=0.2062 | val_loss=0.2329 | val_error=1.0567 rad
# Epoch 16/50 | train_loss=0.1387 | val_loss=0.2240 | val_error=1.0483 rad
# Epoch 17/50 | train_loss=0.1005 | val_loss=0.0886 | val_error=0.6826 rad
# Epoch 18/50 | train_loss=0.0442 | val_loss=0.0333 | val_error=0.2434 rad
# Epoch 19/50 | train_loss=0.0339 | val_loss=0.0531 | val_error=0.2106 rad
# Epoch 20/50 | train_loss=0.0138 | val_loss=0.0094 | val_error=0.1174 rad
# Epoch 21/50 | train_loss=0.0118 | val_loss=0.0415 | val_error=0.3922 rad
# Epoch 22/50 | train_loss=0.0075 | val_loss=0.0037 | val_error=0.0591 rad
# Epoch 23/50 | train_loss=0.0023 | val_loss=0.0040 | val_error=0.1258 rad
# Epoch 24/50 | train_loss=0.0020 | val_loss=0.0099 | val_error=0.2337 rad
# Epoch 25/50 | train_loss=0.0058 | val_loss=0.0114 | val_error=0.2056 rad
# Epoch 26/50 | train_loss=0.0023 | val_loss=0.0010 | val_error=0.0734 rad
# Epoch 27/50 | train_loss=0.0015 | val_loss=0.0016 | val_error=0.0400 rad
# Epoch 28/50 | train_loss=0.0019 | val_loss=0.0053 | val_error=0.1179 rad
# Epoch 29/50 | train_loss=0.0011 | val_loss=0.0012 | val_error=0.0567 rad
# Epoch 30/50 | train_loss=0.0024 | val_loss=0.0012 | val_error=0.0692 rad
# Epoch 31/50 | train_loss=0.0015 | val_loss=0.0006 | val_error=0.0199 rad
# Epoch 32/50 | train_loss=0.0008 | val_loss=0.0005 | val_error=0.0336 rad
# Epoch 33/50 | train_loss=0.0009 | val_loss=0.0012 | val_error=0.0713 rad
# Epoch 34/50 | train_loss=0.0012 | val_loss=0.0007 | val_error=0.0666 rad
# Epoch 35/50 | train_loss=0.0005 | val_loss=0.0005 | val_error=0.0186 rad
# Epoch 36/50 | train_loss=0.0010 | val_loss=0.0034 | val_error=0.1416 rad
# Epoch 37/50 | train_loss=0.0013 | val_loss=0.0010 | val_error=0.0733 rad
# Epoch 38/50 | train_loss=0.0005 | val_loss=0.0008 | val_error=0.0223 rad
# Epoch 39/50 | train_loss=0.0007 | val_loss=0.0011 | val_error=0.0706 rad
# Epoch 40/50 | train_loss=0.0006 | val_loss=0.0004 | val_error=0.0326 rad
# Epoch 41/50 | train_loss=0.0004 | val_loss=0.0004 | val_error=0.0158 rad
# Epoch 42/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0147 rad
# Epoch 43/50 | train_loss=0.0005 | val_loss=0.0003 | val_error=0.0144 rad
# Epoch 44/50 | train_loss=0.0007 | val_loss=0.0003 | val_error=0.0114 rad
# Epoch 45/50 | train_loss=0.0004 | val_loss=0.0003 | val_error=0.0284 rad
# Epoch 46/50 | train_loss=0.0004 | val_loss=0.0003 | val_error=0.0300 rad
# Epoch 47/50 | train_loss=0.0003 | val_loss=0.0004 | val_error=0.0166 rad
# Epoch 48/50 | train_loss=0.0003 | val_loss=0.0006 | val_error=0.0642 rad
# Epoch 49/50 | train_loss=0.0004 | val_loss=0.0005 | val_error=0.0505 rad
# Epoch 50/50 | train_loss=0.0003 | val_loss=0.0004 | val_error=0.0430 rad
# Run 2 finished with a test loss of 0.0004113 and a mean test error of 0.03477 rad.

# %% [markdown]
# Evaluate the final result on the `test_loader` using the function `evaluate_model`.

# %%
# evaluate the trig model on the test set
test_error_across_runs_trig = np.zeros((num_runs,))
for run in range(num_runs):
    model_trig.load_state_dict(
        torch.load(STATEDICTS_DIR / f"task_1b_trig_model_run-{run}.pth")
    )
    run_test_loss, run_test_error = evaluate_model(
        model_trig, test_loader, model_type="trig"
    )
    test_error_across_runs_trig[run] = run_test_error
print(
    f"Prediction error of trig model across runs: {np.mean(test_error_across_runs_trig):.4} += {np.std(test_error_across_runs_trig):.4} rad."
)
# Out:
# Prediction error of trig model across runs: 0.03451 += 0.008605 rad.

# %% [markdown]
# ### Task 1b.2.3 - Analyse model performance (3 points)

# %% [markdown]
# Analyse the model's training loss. Does your training loss decrease step by step? Do you find some magnitude difference between the training loss of $M_{trig}$ with the previous one of $M_θ$? Can you explain why they are different? (1 point)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Compare the prediction estimates for $M_{trig}$ with the plot for $M_θ$. Why does indirectly predicting the angle improve the prediction accuracy? (1 point)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Why is it not sufficient to predict only sin(θ) and use its inverse θ = arcsin(sin(θ)) to get an estimate of the angle? (1 point)

# %% [markdown]
# YOUR ANSWER HERE
